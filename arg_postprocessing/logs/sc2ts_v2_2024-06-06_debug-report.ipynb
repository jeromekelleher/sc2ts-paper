# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing', '/gpfs3/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/bin', '/apps/eb/el8/2023a/epyc/software/Python/3.11.3-GCCcore-12.3.0/easybuild/python', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/lib-dynload', '/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/src/pangonet/src', '/users/kelleher/sbk774/.cache/snakemake/snakemake/source-cache/snakemake-runtime-cache/tmp0_yj8c04/file/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks']);import pickle;snakemake = pickle.loads(b'\x80\x04\x95\x16\x04\x00\x00\x00\x00\x00\x00\x8c\x16snakemake.iocontainers\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94h\x00\x8c\nInputFiles\x94\x93\x94)\x81\x94\x8c\x19sc2ts_v2_2024-06-06.trees\x94a}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x0fh\x00\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbub\x8c\x06output\x94h\x00\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c\x1fsc2ts_v2_2024-06-06_samples.csv\x94\x8c!sc2ts_v2_2024-06-06_resources.csv\x94e}\x94(h\x0b}\x94h\r]\x94(h\x0fh\x10eh\x0fh\x12)\x81\x94}\x94h\x15h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbub\x8c\r_params_store\x94h\x00\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0b}\x94h\r]\x94(h\x0fh\x10eh\x0fh\x12)\x81\x94}\x94h\x15h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x00\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\x13sc2ts_v2_2024-06-06\x94a}\x94(h\x0b}\x94\x8c\tDR_PREFIX\x94K\x00N\x86\x94sh\r]\x94(h\x0fh\x10eh\x0fh\x12)\x81\x94}\x94h\x15h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbh9h6ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x00\x8c\x0cResourceList\x94\x93\x94)\x81\x94(\x8c\x04/tmp\x94K\x01K\x01e}\x94(h\x0b}\x94(\x8c\x06tmpdir\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06_cores\x94K\x02N\x86\x94uh\r]\x94(h\x0fh\x10eh\x0fh\x12)\x81\x94}\x94h\x15h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbhHhEhJK\x01hLK\x01ub\x8c\x03log\x94h\x00\x8c\x03Log\x94\x93\x94)\x81\x94\x8c+logs/sc2ts_v2_2024-06-06_debug-report.ipynb\x94a}\x94(h\x0b}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\r]\x94(h\x0fh\x10eh\x0fh\x12)\x81\x94}\x94h\x15h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbhZhWub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\x0cdebug_report\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cY/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks\x94ub.');from snakemake.logging import logger;from snakemake.iocontainers import Snakemake;import os; os.chdir(r'/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing');
######## snakemake preamble end #########

# %%
import tszip
import sc2ts.debug as sd

# %%
ts = tszip.load(snakemake.input[0])
ts
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
# ...

# %%
ti = sd.ArgInfo(ts, show_progress=False)
ti
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#     <tr>
#       <th>property</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>latest_sample</th>
#       <td>2024-06-06</td>
#     </tr>
#     <tr>
#       <th>samples</th>
#       <td>1471706</td>
#     </tr>
#     <tr>
#       <th>nodes</th>
#       <td>1731086</td>
#     </tr>
#     <tr>
#       <th>exact_matches</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>mc_nodes</th>
#       <td>96482</td>
#     </tr>
#     <tr>
#       <th>pr_nodes</th>
#       <td>52529</td>
#     </tr>
#     <tr>
#       <th>re_nodes</th>
#       <td>1289</td>
# ...

# %%
ti.plot_resources();

# %%
ti.plot_samples_per_day();
# Out:
# /tmp/ipykernel_2361820/500035874.py:1: UserWarning: No samples for Scorpio . present
#   ti.plot_samples_per_day();

# %%
ti.plot_mutations_per_node_distribution();

# %%
ti.plot_mutations_per_site_distribution();

# %%
ti.plot_mutations_per_site();

# %%
ti.plot_mutations_per_site(annotate_threshold=0.10, select=ti.mutations_is_reversion);

# %%
ti.plot_deletion_samples_per_site(annotate_threshold=0.1);

# %%
ti.plot_branch_length_distributions();

# %%
ti.plot_missing_sites_per_sample();

# %%
ti.plot_deletion_sites_per_sample();

# %%
ti.plot_deletion_overlaps();

# %%
ti.plot_mutation_spectrum();

# %%
ti.recombinants_summary();
# Out:
# RE: 233437 has more than two parents. Skipping.
# RE: 460790 interval_right >= interval_left; moving from 22027to 22026
# RE: 489825 interval_right >= interval_left; moving from 22027to 22026
# RE: 579585 interval_right >= interval_left; moving from 22027to 22026
# RE: 597638 interval_right >= interval_left; moving from 22027to 22026
# RE: 623743 interval_right >= interval_left; moving from 22027to 22026
# RE: 628790 interval_right >= interval_left; moving from 22027to 22026
# RE: 663691 interval_right >= interval_left; moving from 22027to 22026
# RE: 673179 interval_right >= interval_left; moving from 22027to 22026
# RE: 687638 interval_right >= interval_left; moving from 22027to 22026
# RE: 691401 interval_right >= interval_left; moving from 22027to 22026
# RE: 694629 interval_right >= interval_left; moving from 22027to 22026
# RE: 702675 interval_right >= interval_left; moving from 22027to 22026
# RE: 707679 interval_right >= interval_left; moving from 22027to 22026
# ...

# %%
ti.samples_summary().to_csv(snakemake.output[0])

# %%
ti.resources_summary().to_csv(snakemake.output[1])
