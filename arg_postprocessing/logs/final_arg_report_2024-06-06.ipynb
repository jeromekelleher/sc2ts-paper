# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing', '/gpfs3/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/bin', '/apps/eb/el8/2023a/epyc/software/Python/3.11.3-GCCcore-12.3.0/easybuild/python', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/lib-dynload', '/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/src/pangonet/src', '/users/kelleher/sbk774/.cache/snakemake/snakemake/source-cache/snakemake-runtime-cache/tmpiujykbmy/file/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks']);import pickle;snakemake = pickle.loads(b"\x80\x04\x95\xe0\x04\x00\x00\x00\x00\x00\x00\x8c\x16snakemake.iocontainers\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94h\x00\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c?sc2ts_v2_2024-06-06_pr_pp_mp_aph_bps_pango_dated_mmps.trees.tsz\x94\x8c'sc2ts_2024-06-06_intersection.trees.tsz\x94\x8c-usher_2024-06-06_intersection_ds_di.trees.tsz\x94\x8c\x18usher_viridian.trees.tsz\x94e}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x12h\x00\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbub\x8c\x06output\x94h\x00\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c#sc2ts_viridian_2024-06-06.trees.tsz\x94\x8c)sc2ts_viridian_inter_2024-06-06.trees.tsz\x94\x8c)usher_viridian_inter_2024-06-06.trees.tsz\x94e}\x94(h\x0e}\x94h\x10]\x94(h\x12h\x13eh\x12h\x15)\x81\x94}\x94h\x18h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbub\x8c\r_params_store\x94h\x00\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0e}\x94h\x10]\x94(h\x12h\x13eh\x12h\x15)\x81\x94}\x94h\x18h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x00\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\n2024-06-06\x94a}\x94(h\x0e}\x94\x8c\x04DATE\x94K\x00N\x86\x94sh\x10]\x94(h\x12h\x13eh\x12h\x15)\x81\x94}\x94h\x18h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sb\x8c\x04DATE\x94h:ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x00\x8c\x0cResourceList\x94\x93\x94)\x81\x94(\x8c\x04/tmp\x94K\x01K\x01e}\x94(h\x0e}\x94(\x8c\x06tmpdir\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06_cores\x94K\x02N\x86\x94uh\x10]\x94(h\x12h\x13eh\x12h\x15)\x81\x94}\x94h\x18h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbhMhJhOK\x01hQK\x01ub\x8c\x03log\x94h\x00\x8c\x03Log\x94\x93\x94)\x81\x94\x8c&logs/final_arg_report_2024-06-06.ipynb\x94a}\x94(h\x0e}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x10]\x94(h\x12h\x13eh\x12h\x15)\x81\x94}\x94h\x18h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbh_h\\ub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\x10final_arg_report\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cY/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks\x94ub.");from snakemake.logging import logger;from snakemake.iocontainers import Snakemake;import os; os.chdir(r'/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing');
######## snakemake preamble end #########

# %%
import sc2ts
import tszip
import shutil

# %%
# Copy the dated ARGs to their published viridian names. The full usher
# tree (the last input) is date-independent and published separately, so
# it is loaded directly below rather than copied here.
assert len(snakemake.input) == 4 and len(snakemake.output) == 3
for fin, fout in zip(snakemake.input[:3], snakemake.output):
    shutil.copy(fin, fout)

# %%
sc2ts_viridian = snakemake.output[0]
sc2ts_viridian_inter = snakemake.output[1]
usher_viridian_inter = snakemake.output[2]
# The usher tree is published separately (undated) and passed as the last input.
usher_viridian = snakemake.input[3]

# %% [markdown]
# # Main sc2ts ARG
#
# Built from Viridian data up to 2024-06-06. Internal nodes have been dated using tsdate, and contains deletions and highly homoplasic sites post-hoc mapped on by parsimony.

# %%
ts_sc2ts = tszip.load(sc2ts_viridian)
ts_sc2ts
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
# ...

# %%
sc2ts.node_data(ts_sc2ts)
# Out:
#              pango         sample_id                 scorpio  node_id  \
# 0                B  Vestigial_ignore                       .        0
# 1                B   Wuhan/Hu-1/2019                       .        1
# 2                A       SRR11772659                       .        2
# 3                B       SRR11397727                       .        3
# 4                B       SRR11397730                       .        4
# ...            ...               ...                     ...      ...
# 3424141     HV.1.1                      Omicron (XBB.1-like)  3424141
# 3424142  BQ.1.1.29                       Omicron (BA.5-like)  3424142
# 3424143     BA.1.1                       Omicron (BA.1-like)  3424143
# 3424144      AY.75                    Delta (B.1.617.2-like)  3424144
# 3424145    XBB.1.5                        Omicron (XBB-like)  3424145
#
#          is_sample  is_recombinant  num_mutations       date
# 0            False           False              0 2019-11-19
# ...

# %%
sc2ts.mutation_data(ts_sc2ts)
# Out:
#          mutation_id  site_id  position  parent     node inherited_state  \
# 0                  0        0        56      -1     9044               G
# 1                  1        0        56      -1   664838               G
# 2                  2        0        56      -1   479708               G
# 3                  3        0        56      -1   549470               G
# 4                  4        0        56      -1   802956               G
# ...              ...      ...       ...     ...      ...             ...
# 2761029      2761029    29639     29803      -1  1850758               C
# 2761030      2761030    29639     29803      -1  1868897               C
# 2761031      2761031    29639     29803      -1  1875756               C
# 2761032      2761032    29639     29803      -1  1869637               C
# 2761033      2761033    29639     29803      -1  1891232               C
#
#         derived_state       date
# 0                   T 2020-03-22
# ...

# %%
ts_sc2ts.metadata
# Out:
# {'time_zero_date': '2024-06-06'}

# %% [markdown]
# # Main UShER tree
#
# Translation of the Viridian UShER tree to tskit format. Time units are uncalibrated and branch-lengths are not meaningful.

# %%
ts_usher = tszip.load(usher_viridian)
ts_usher
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
# ...

# %%
sc2ts.node_data(ts_usher)
# Out:
#            sample_id  node_id  is_sample  is_recombinant  num_mutations  \
# 0         ERR4085584        0       True           False              0
# 1         ERR4086315        1       True           False              0
# 2         ERR4091746        2       True           False              0
# 3         ERR4165155        3       True           False              0
# 4         ERR4204267        4       True           False              0
# ...              ...      ...        ...             ...            ...
# 5345014  SRR21886505  5345014       True           False              5
# 5345015  node_763111  5345015      False           False              1
# 5345016  SRR21635465  5345016       True           False              0
# 5345017  node_763112  5345017      False           False              1
# 5345018  SRR21795271  5345018       True           False              0
#
#               date
# 0       2024-06-06
# 1       2024-06-06
# 2       2024-06-06
# 3       2024-06-06
# ...

# %%
sc2ts.mutation_data(ts_usher)
# Out:
#          mutation_id  site_id  position  parent     node inherited_state  \
# 0                  0        0       267      -1  1235535               T
# 1                  1        0       267      -1  5297533               T
# 2                  2        1       269      -1   246856               G
# 3                  3        1       269      -1  2677518               G
# 4                  4        1       269      -1  4780608               G
# ...              ...      ...       ...     ...      ...             ...
# 3364836      3364836    27507     29671      -1  4693921               A
# 3364837      3364837    27507     29671      -1  4741596               A
# 3364838      3364838    27507     29671      -1  4754269               A
# 3364839      3364839    27507     29671      -1  4806294               A
# 3364840      3364840    27507     29671      -1  5084179               A
#
#         derived_state       date
# 0                   A 2024-06-06
# ...

# %%
ts_usher.metadata
# Out:
# {'time_zero_date': '2024-06-06'}

# %% [markdown]
# # Intersection sc2ts ARG
#
# Subset of main sc2ts ARG subset to the intersection of samples and sites common to sc2ts and UShER. Internal nodes have **not** been dated by tsdate and so will likely differ from the node dates on the main ARG.

# %%
ts_sc2ts_inter = tszip.load(sc2ts_viridian_inter)
ts_sc2ts_inter
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
# ...

# %%
sc2ts.node_data(ts_sc2ts_inter)
# Out:
#                 sample_id  node_id  is_sample  is_recombinant  num_mutations  \
# 0             SRR11772659        0       True           False              1
# 1             SRR11397727        1       True           False              0
# 2             SRR11597198        2       True           False              0
# 3             SRR11597221        3       True           False              0
# 4             SRR11597143        4       True           False              2
# ...                   ...      ...        ...             ...            ...
# 3414361                    3414361      False           False              1
# 3414362                    3414362      False           False              1
# 3414363                    3414363      False           False              1
# 3414364   Wuhan/Hu-1/2019  3414364      False           False              0
# 3414365  Vestigial_ignore  3414365      False           False              0
#
#               date
# 0       2020-01-19
# ...

# %%
sc2ts.mutation_data(ts_sc2ts_inter)
# Out:
#          mutation_id  site_id  position  parent     node inherited_state  \
# 0                  0        1       269      -1     5344               G
# 1                  1        1       269      -1  3392300               G
# 2                  2        1       269      -1    80920               G
# 3                  3        1       269      -1   100059               G
# 4                  4        1       269      -1   105177               G
# ...              ...      ...       ...     ...      ...             ...
# 2646029      2646029    27507     29671      -1  1506572               A
# 2646030      2646030    27507     29671      -1  3127074               A
# 2646031      2646031    27507     29671      -1  1576732               A
# 2646032      2646032    27507     29671      -1  1580226               A
# 2646033      2646033    27507     29671      -1  3125223               A
#
#         derived_state       date
# 0                   A 2020-04-06
# ...

# %%
ts_sc2ts.metadata
# Out:
# {'time_zero_date': '2024-06-06'}

# %% [markdown]
# # Intersection UShER ARG
#
# Subset of main UShER ARG subset to the intersection of samples and sites common to both. Internal nodes have been dated by tsdate.

# %%
ts_usher_inter =tszip.load(usher_viridian_inter)
ts_usher_inter
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
# ...

# %%
sc2ts.node_data(ts_usher_inter)
# Out:
#           Date_tree    sample_id  node_id  is_sample  is_recombinant  \
# 0        2020-01-19  SRR11772659        0       True           False
# 1        2020-01-24  SRR11397727        1       True           False
# 2        2020-01-25  SRR11597198        2       True           False
# 3        2020-01-25  SRR11597221        3       True           False
# 4        2020-01-28  SRR11597143        4       True           False
# ...             ...          ...      ...        ...             ...
# 3754900                node_1696  3754900      False           False
# 3754901                node_1695  3754901      False           False
# 3754902                node_1694  3754902      False           False
# 3754903                node_1693  3754903      False           False
# 3754904                   node_1  3754904      False           False
#
#          num_mutations
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# ...

# %%
sc2ts.mutation_data(ts_usher_inter)
# Out:
#          mutation_id  site_id  position  parent     node inherited_state  \
# 0                  0        1       269      -1  3272126               G
# 1                  1        1       269      -1  3727494               G
# 2                  2        1       269      -1   100059               G
# 3                  3        1       269      -1    80920               G
# 4                  4        1       269      -1  3717964               G
# ...              ...      ...       ...     ...      ...             ...
# 2474754      2474754    27507     29671      -1  1499516               A
# 2474755      2474755    27507     29671      -1  3414533               A
# 2474756      2474756    27507     29671      -1  1576732               A
# 2474757      2474757    27507     29671      -1  3400816               A
# 2474758      2474758    27507     29671      -1  1580226               A
#
#         derived_state
# 0                   A
# 1                   A
# ...

# %%
ts_usher_inter.metadata
# Out:
# {'sc2ts': {'date': '2024-06-06'}}
