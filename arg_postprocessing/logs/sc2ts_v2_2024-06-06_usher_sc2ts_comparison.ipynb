# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing', '/gpfs3/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/bin', '/apps/eb/el8/2023a/epyc/software/Python/3.11.3-GCCcore-12.3.0/easybuild/python', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/lib-dynload', '/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/src/pangonet/src', '/users/kelleher/sbk774/.cache/snakemake/snakemake/source-cache/snakemake-runtime-cache/tmpcn3b7hlt/file/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks']);import pickle;snakemake = pickle.loads(b"\x80\x04\x95v\x04\x00\x00\x00\x00\x00\x00\x8c\x16snakemake.iocontainers\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94h\x00\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c#usher_2024-06-06_intersection.trees\x94\x8c'usher_2024-06-06_intersection_asp.trees\x94\x8c%usher_2024-06-06_intersection_asp.csv\x94\x8c#sc2ts_2024-06-06_intersection.trees\x94\x8c'sc2ts_2024-06-06_intersection_asp.trees\x94\x8c%sc2ts_2024-06-06_intersection_asp.csv\x94e}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x14h\x00\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbub\x8c\x06output\x94h\x00\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94}\x94(h\x10}\x94h\x12]\x94(h\x14h\x15eh\x14h\x17)\x81\x94}\x94h\x1ah\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbub\x8c\r_params_store\x94h\x00\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x10}\x94h\x12]\x94(h\x14h\x15eh\x14h\x17)\x81\x94}\x94h\x1ah\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x00\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x10}\x94h\x12]\x94(h\x14h\x15eh\x14h\x17)\x81\x94}\x94h\x1ah\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x00\x8c\x0cResourceList\x94\x93\x94)\x81\x94(\x8c\x04/tmp\x94K\x01K\x01e}\x94(h\x10}\x94(\x8c\x06tmpdir\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06_cores\x94K\x02N\x86\x94uh\x12]\x94(h\x14h\x15eh\x14h\x17)\x81\x94}\x94h\x1ah\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbhHhEhJK\x01hLK\x01ub\x8c\x03log\x94h\x00\x8c\x03Log\x94\x93\x94)\x81\x94\x8c!logs/usher_sc2ts_comparison.ipynb\x94a}\x94(h\x10}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x12]\x94(h\x14h\x15eh\x14h\x17)\x81\x94}\x94h\x1ah\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbhZhWub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\x16usher_sc2ts_comparison\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cY/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks\x94ub.");from snakemake.logging import logger;from snakemake.iocontainers import Snakemake;import os; os.chdir(r'/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing');
######## snakemake preamble end #########

# %%
import pandas as pd
import sc2ts
import tszip
import numpy as np
import matplotlib.pyplot as plt

# %%
tsu = tszip.load(snakemake.input[0])
tsup = tszip.load(snakemake.input[1])
dfup = pd.read_csv(snakemake.input[2], index_col=0)

# %%
tss = tszip.load(snakemake.input[3])
tssp = tszip.load(snakemake.input[4])
dfsp = pd.read_csv(snakemake.input[5], index_col=0)

# %% [markdown]
# # Base ARGs
#
# Comparison of the two base ARGs (tsu is Usher, tss is sc2ts)

# %%
tsu
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>1</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>uncalibrated</td></tr>
#                             <tr><td>Sample Nodes</td><td>2 827 813</td></tr>
#                             <tr><td>Total Size</td><td>370.0 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#                     time_zero_date: 2024-06-06<br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>3 405 806</td>
#                 <td>103.9 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>2 273 199</td>
#                 <td>80.2 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>3 405 807</td>
#                 <td>159.2 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>4</td>
#                 <td>2.2 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>27 505</td>
#                 <td>671.5 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>25 May, 2026 at 11:01:26 AM</td>
#                     <td>tskit</td>
#                     <td>1.0.2</td>
#                     <td>delete_sites</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: tskit<br/>version: 1.0.2<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     command: delete_sites<br/>TODO: add parameters<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: cloudcomp100.hpc.in.bmrc.ox.ac<br/>.uk<br/>release: 4.18.0-553.123.1.el8_10.x86_64<br/>version: #1 SMP Tue May 5 15:46:59 UTC<br/>2026<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">kastore:</span>
#                 <details >
#                     <summary>dict</summary>
#                     version: 2.1.2<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#
#                         </details>

# %%
tss
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>466</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>days</td></tr>
#                             <tr><td>Sample Nodes</td><td>2 827 813</td></tr>
#                             <tr><td>Total Size</td><td>336.2 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#                     time_zero_date: 2024-06-06<br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>3 096 523</td>
#                 <td>94.5 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>2 416 521</td>
#                 <td>85.3 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>3 095 327</td>
#                 <td>129.9 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>1 604</td>
#                 <td>2.2 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>27 505</td>
#                 <td>671.5 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>25 May, 2026 at 11:01:26 AM</td>
#                     <td>tskit</td>
#                     <td>1.0.2</td>
#                     <td>delete_sites</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: tskit<br/>version: 1.0.2<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     command: delete_sites<br/>TODO: add parameters<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: cloudcomp100.hpc.in.bmrc.ox.ac<br/>.uk<br/>release: 4.18.0-553.123.1.el8_10.x86_64<br/>version: #1 SMP Tue May 5 15:46:59 UTC<br/>2026<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">kastore:</span>
#                 <details >
#                     <summary>dict</summary>
#                     version: 2.1.2<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#
#                         </details>

# %%
data = []
for name, ts in [("usher", tsu), ("sc2ts", tss)]:
    data.append({
        "name": name,
        "trees": ts.num_trees,
        "nodes": ts.num_nodes,
        "edges": ts.num_edges,
        "mutations": ts.num_mutations,
        "samples": ts.num_samples,
    })
pd.DataFrame(data)
# Out:
#     name  trees    nodes    edges  mutations  samples
# 0  usher      1  3405807  3405806    2273199  2827813
# 1  sc2ts    466  3095327  3096523    2416521  2827813

# %%
assert tsu.reference_sequence.metadata == tss.reference_sequence.metadata
assert tsu.reference_sequence.data == tss.reference_sequence.data

# %%
diff = tss.num_mutations - tsu.num_mutations
diff
# Out:
# 143322

# %%
f"Difference in mutations = {diff /  tss.num_mutations:.2%}"
# Out:
# 'Difference in mutations = 5.93%'

# %% [markdown]
# The differences are not uniform along the genome, with sc2ts having significantly more mutations at a handful of positions

# %%
_, ax = plt.subplots(1, figsize=(16, 4))
ax.plot(dfup.site, dfsp.old - dfup.old) 
ax.set_ylabel("Difference between mutation counts")
# Out:
# Text(0, 0.5, 'Difference between mutation counts')

# %%
diff = tsu.num_nodes - tss.num_nodes
diff
# Out:
# 310480

# %%
f"Difference in nodes = {diff /  tsu.num_nodes:.2%}"
# Out:
# 'Difference in nodes = 9.12%'

# %% [markdown]
# There is a significant difference in the number of nodes, although this is at least partially explained by sc2ts allowing samples to be internal:

# %%
tree = tsu.first()
np.sum(tree.num_children_array[tsu.samples()] > 0)
# Out:
# np.int64(0)

# %%
tree = tss.first()
np.sum(tree.num_children_array[tss.samples()] > 0)
# Out:
# np.int64(335810)

# %% [markdown]
# # All sites parsimony ARGs
#
# Comparison of the ARGs we get when we map all the deletions back on (only changes mutations)

# %%
tsup.num_mutations
# Out:
# 12742016

# %%
tssp.num_mutations
# Out:
# 15567664

# %%
diff = tssp.num_mutations - tsup.num_mutations
diff
# Out:
# 2825648

# %%
f"Difference in mutations = {diff /  tssp.num_mutations:.2%}"
# Out:
# 'Difference in mutations = 18.15%'

# %% [markdown]
# There is a significant difference between the two - what is this driven by? Let's look at the parsimony reports

# %%
dfup
# Out:
#         site  old  new  intersection
# 0          1    0    1             0
# 1          2    0    1             0
# 2          3    0    1             0
# 3          4    0    1             0
# 4          5    0    1             0
# ...      ...  ...  ...           ...
# 29898  29899    0    1             0
# 29899  29900    0    1             0
# 29900  29901    0    1             0
# 29901  29902    0    1             0
# 29902  29903    0    1             0
#
# [29903 rows x 4 columns]

# %%
dfsp
# Out:
#         site  old  new  intersection
# 0          1    0    1             0
# 1          2    0    1             0
# 2          3    0    1             0
# 3          4    0    1             0
# 4          5    0    1             0
# ...      ...  ...  ...           ...
# 29898  29899    0    1             0
# 29899  29900    0    1             0
# 29900  29901    0    1             0
# 29901  29902    0    1             0
# 29902  29903    0    1             0
#
# [29903 rows x 4 columns]

# %%
data = []
for name, df in [("sc2ts", dfsp), ("usher", dfup)]:
    data.append({
        "name": name,
        "identical": np.sum(df.old == df.new),
        "exact_inter": np.sum(df.old == df.intersection),
        "exact_inter10": np.sum((df.old == df.intersection) & (df.new - df.old < 10)),
        "exact_inter100": np.sum((df.old == df.intersection) & (df.new - df.old < 100)),
    })
pd.DataFrame(data)
# Out:
#     name  identical  exact_inter  exact_inter10  exact_inter100
# 0  sc2ts      18649        27353          22996           25659
# 1  usher      18133        26792          22975           25401

# %% [markdown]
# A large majority of the sites are identical before and after remapping with parsimony, and about 25k sites recapture the existing mutations exactly with small number of additional mutations.
#
# The differences seem to be from a small number of sites doing very badly. If we plot the number of remapped mutations in sc2ts vs usher along the genome.

# %%
_, ax = plt.subplots(1, figsize=(16, 4))
ax.plot(dfup.site, dfsp.new - dfup.new) 
ax.set_ylabel("Difference between remapped mutation counts")
ax.set_ylim((-2000, 2000));

# %% [markdown]
# Sc2ts seems to do particularly badly in the righthand flank, which accounts for a large fraction of the excess mutations

# %%
dfsp[dfsp.site > 29600]
# Out:
#         site  old   new  intersection
# 29600  29601    4  9041             4
# 29601  29602   16  9066            15
# 29602  29603    8  9061             8
# 29603  29604   54  9116            54
# 29604  29605    3  9075             3
# ...      ...  ...   ...           ...
# 29898  29899    0     1             0
# 29899  29900    0     1             0
# 29900  29901    0     1             0
# 29901  29902    0     1             0
# 29902  29903    0     1             0
#
# [303 rows x 4 columns]

# %%
dfsp[dfsp.site > 29600].new.sum() - dfup[dfup.site > 29600].new.sum()
# Out:
# np.int64(1633876)

# %% [markdown]
# Usher seems to do badly in one particular place:

# %%
diffs = dfsp.new - dfup.new
dfup[diffs < -1000]
# Out:
#         site  old    new  intersection
# 634      635    0   3352             0
# 685      686   39  12553            37
# 686      687   61  12579            60
# 687      688  135  12652           133
# 688      689   75  12597            72
# 689      690  119  12643           114
# 690      691  115  12614           110
# 691      692   84  12615            77
# 692      693   37  12560            36
# 693      694  163  12641           153
# 21609  21610    2   2247             2
# 21611  21612    0   2069             0
# 21612  21613    0   2093             0
# 21614  21615    1   2142             1
# 21615  21616    0   2020             0
# 21616  21617    1   2398             1
# 21618  21619    0   2048             0
# 21619  21620    0   2022             0
# 21620  21621   56   2782             0
# 21623  21624    5   3000             4
# 21624  21625    0   2068             0
# 21625  21626    0   2018             0
# 21626  21627    6   3094             5
# 21631  21632    1   2060             1
# 21632  21633  109   2191           108
# 21633  21634   19   1971            19
# 21635  21636  184   2130           184
# 21636  21637    0   2384             0
# 21637  21638  400   2349           400
# 21638  21639    1   2461             1
# 21639  21640    0   2005             0
# 21640  21641    3   2805             3
# 21986  21987    0  25549             0
# 21990  21991    9   5355             8
# 21991  21992   33   5444            31
# 21992  21993   79   5365            77
# 22193  22194  259  14387           222
# 22194  22195   83  14223            83
# 22195  22196   61  14143            58
# 22196  22197  119  13962           119
# 22197  22198   23  13840            23
# 22201  22202   37  13799            37
# 22203  22204   42  13799            42
# 22785  22786  171   8720           170
# 22881  22882   73  11946            70
# 23947  23948  347  12526           346
