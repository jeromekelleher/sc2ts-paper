# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing', '/gpfs3/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/bin', '/apps/eb/el8/2023a/epyc/software/Python/3.11.3-GCCcore-12.3.0/easybuild/python', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/lib-dynload', '/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/src/pangonet/src', '/users/kelleher/sbk774/.cache/snakemake/snakemake/source-cache/snakemake-runtime-cache/tmpcn3b7hlt/file/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks']);import pickle;snakemake = pickle.loads(b"\x80\x04\x95\xc1\x04\x00\x00\x00\x00\x00\x00\x8c\x16snakemake.iocontainers\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94h\x00\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c?sc2ts_v2_2024-06-06_pr_pp_mp_aph_bps_pango_dated_mmps.trees.tsz\x94\x8c usher_v1_2024-06-06_mm.trees.tsz\x94\x8c'sc2ts_2024-06-06_intersection.trees.tsz\x94\x8c-usher_2024-06-06_intersection_ds_di.trees.tsz\x94e}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x12h\x00\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbub\x8c\x06output\x94h\x00\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c\x1dsc2ts_viridian_v2.0.trees.tsz\x94\x8c\x1dusher_viridian_v1.0.trees.tsz\x94\x8c#sc2ts_viridian_inter_v2.0.trees.tsz\x94\x8c#usher_viridian_inter_v2.0.trees.tsz\x94e}\x94(h\x0e}\x94h\x10]\x94(h\x12h\x13eh\x12h\x15)\x81\x94}\x94h\x18h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbub\x8c\r_params_store\x94h\x00\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0e}\x94h\x10]\x94(h\x12h\x13eh\x12h\x15)\x81\x94}\x94h\x18h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x00\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x0e}\x94h\x10]\x94(h\x12h\x13eh\x12h\x15)\x81\x94}\x94h\x18h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x00\x8c\x0cResourceList\x94\x93\x94)\x81\x94(\x8c\x04/tmp\x94K\x01K\x01e}\x94(h\x0e}\x94(\x8c\x06tmpdir\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06_cores\x94K\x02N\x86\x94uh\x10]\x94(h\x12h\x13eh\x12h\x15)\x81\x94}\x94h\x18h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbhJhGhLK\x01hNK\x01ub\x8c\x03log\x94h\x00\x8c\x03Log\x94\x93\x94)\x81\x94\x8c\x1blogs/final_arg_report.ipynb\x94a}\x94(h\x0e}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x10]\x94(h\x12h\x13eh\x12h\x15)\x81\x94}\x94h\x18h\x12sbh\x13h\x15)\x81\x94}\x94h\x18h\x13sbh\\hYub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\nfinal_args\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cY/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks\x94ub.");from snakemake.logging import logger;from snakemake.iocontainers import Snakemake;import os; os.chdir(r'/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing');
######## snakemake preamble end #########

# %%
import sc2ts
import tszip
import shutil

# %%
assert len(snakemake.input) == len(snakemake.output) == 4
for fin, fout in zip(snakemake.input, snakemake.output):
    shutil.copy(fin, fout)

# %%
sc2ts_viridian = snakemake.output[0]
usher_viridian = snakemake.output[1]
sc2ts_viridian_inter = snakemake.output[2]
usher_viridian_inter = snakemake.output[3]

# %% [markdown]
# # Main sc2ts ARG
#
# Built from Viridian data up to 2023-02-21. Internal nodes have been dated using tsdate, and contains deletions and highly homoplasic sites post-hoc mapped on by parsimony.

# %%
ts_sc2ts = tszip.load(sc2ts_viridian)
ts_sc2ts
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>465</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>days</td></tr>
#                             <tr><td>Sample Nodes</td><td>2 834 524</td></tr>
#                             <tr><td>Total Size</td><td>459.5 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#                     time_zero_date: 2024-06-06<br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>3 105 534</td>
#                 <td>94.8 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>2 533 634</td>
#                 <td>89.4 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>3 104 348</td>
#                 <td>248.7 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>1 604</td>
#                 <td>2.2 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>29 892</td>
#                 <td>729.8 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>18 May, 2026 at 01:50:26 PM</td>
#                     <td>sc2ts</td>
#                     <td>1.0.3.dev10</td>
#                     <td>minimise_metadata</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: sc2ts<br/>version: 1.0.3.dev10<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     command: minimise_metadata<br/>
#             <div>
#                 <span class="tskit-details-label">field_mapping:</span>
#                 <details >
#                     <summary>dict</summary>
#                     strain: sample_id<br/>pango: pango<br/>scorpio: scorpio<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: cloudcomp100.hpc.in.bmrc.ox.ac<br/>.uk<br/>release: 4.18.0-553.123.1.el8_10.x86_64<br/>version: #1 SMP Tue May 5 15:46:59 UTC<br/>2026<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">kastore:</span>
#                 <details >
#                     <summary>dict</summary>
#                     version: 2.1.2<br/>

# %%
sc2ts.node_data(ts_sc2ts)
# Out:
#           pango         sample_id                 scorpio  node_id  is_sample  \
# 0             B  Vestigial_ignore                       .        0      False
# 1             B   Wuhan/Hu-1/2019                       .        1      False
# 2             A       SRR11772659                       .        2       True
# 3             B       SRR11397727                       .        3       True
# 4             B       SRR11397730                       .        4       True
# ...         ...               ...                     ...      ...        ...
# 3104343  AY.119                    Delta (B.1.617.2-like)  3104343      False
# 3104344    AY.9                    Delta (B.1.617.2-like)  3104344      False
# 3104345    AY.3                    Delta (B.1.617.2-like)  3104345      False
# 3104346  BA.1.1                       Omicron (BA.1-like)  3104346      False
# 3104347   AY.75                    Delta (B.1.617.2-like)  3104347      False
#
#          is_recombinant  num_mutations       date
# 0                 False              0 2019-11-19
# 1                 False              0 2019-12-26
# 2                 False              1 2020-01-19
# 3                 False              0 2020-01-24
# 4                 False              0 2020-01-24
# ...                 ...            ...        ...
# 3104343           False              3 2021-05-17
# 3104344           False              7 2021-04-12
# 3104345           False              1 2021-05-15
# 3104346           False              1 2021-11-05
# 3104347           False              9 2021-05-17
#
# [3104348 rows x 8 columns]

# %%
sc2ts.mutation_data(ts_sc2ts)
# Out:
#          mutation_id  site_id  position  parent     node inherited_state  \
# 0                  0       24        25      -1   693423               T
# 1                  1       37        38      -1    14150               A
# 2                  2       42        43      -1   368554               T
# 3                  3       42        43      -1   460861               T
# 4                  4       42        43      -1   724113               T
# ...              ...      ...       ...     ...      ...             ...
# 2533629      2533629    29838     29850      -1   747264               A
# 2533630      2533630    29838     29850      -1   777583               A
# 2533631      2533631    29838     29850      -1  1039587               A
# 2533632      2533632    29838     29850      -1  1244209               A
# 2533633      2533633    29838     29850      -1  1224444               A
#
#         derived_state       date
# 0                   A 2021-09-14
# 1                   G 2020-04-21
# 2                   A 2021-07-17
# 3                   C 2021-07-24
# 4                   C 2021-08-21
# ...               ...        ...
# 2533629             G 2021-10-18
# 2533630             G 2021-10-21
# 2533631             G 2021-12-10
# 2533632             G 2022-01-12
# 2533633             G 2022-01-31
#
# [2533634 rows x 8 columns]

# %%
ts_sc2ts.metadata
# Out:
# {'time_zero_date': '2024-06-06'}

# %% [markdown]
# # Main UShER tree
#
# Translation of the Viridian UShER tree to tskit format. Time units are uncalibrated and branch-lengths are not meaningful.

# %%
ts_usher = tszip.load(usher_viridian)
ts_usher
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>1</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>uncalibrated</td></tr>
#                             <tr><td>Sample Nodes</td><td>4 471 579</td></tr>
#                             <tr><td>Total Size</td><td>522.1 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#                     time_zero_date: 2024-06-06<br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>5 345 018</td>
#                 <td>163.1 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>3 364 841</td>
#                 <td>118.7 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>5 345 019</td>
#                 <td>198.8 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>2</td>
#                 <td>1.2 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>27 508</td>
#                 <td>671.6 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>14 May, 2026 at 11:41:09 PM</td>
#                     <td>sc2ts</td>
#                     <td>1.0.3.dev10</td>
#                     <td>minimise_metadata</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: sc2ts<br/>version: 1.0.3.dev10<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     command: minimise_metadata<br/>
#             <div>
#                 <span class="tskit-details-label">field_mapping:</span>
#                 <details >
#                     <summary>dict</summary>
#                     strain: sample_id<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: cloudcomp100.hpc.in.bmrc.ox.ac<br/>.uk<br/>release: 4.18.0-553.123.1.el8_10.x86_64<br/>version: #1 SMP Tue May 5 15:46:59 UTC<br/>2026<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">kastore:</span>
#                 <details >
#                     <summary>dict</summary>
#                     version: 2.1.2<br/>
#                 </details>

# %%
sc2ts.node_data(ts_usher)
# Out:
#            sample_id  node_id  is_sample  is_recombinant  num_mutations  \
# 0         ERR4085584        0       True           False              0
# 1         ERR4086315        1       True           False              0
# 2         ERR4091746        2       True           False              0
# 3         ERR4165155        3       True           False              0
# 4         ERR4204267        4       True           False              0
# ...              ...      ...        ...             ...            ...
# 5345014  SRR21886505  5345014       True           False              5
# 5345015  node_763111  5345015      False           False              1
# 5345016  SRR21635465  5345016       True           False              0
# 5345017  node_763112  5345017      False           False              1
# 5345018  SRR21795271  5345018       True           False              0
#
#               date
# 0       2024-06-06
# 1       2024-06-06
# 2       2024-06-06
# 3       2024-06-06
# 4       2024-06-06
# ...            ...
# 5345014 2024-06-06
# 5345015 2024-06-04
# 5345016 2024-06-06
# 5345017 2024-06-05
# 5345018 2024-06-06
#
# [5345019 rows x 6 columns]

# %%
sc2ts.mutation_data(ts_usher)
# Out:
#          mutation_id  site_id  position  parent     node inherited_state  \
# 0                  0        0       267      -1  1235535               T
# 1                  1        0       267      -1  5297533               T
# 2                  2        1       269      -1   246856               G
# 3                  3        1       269      -1  2677518               G
# 4                  4        1       269      -1  4780608               G
# ...              ...      ...       ...     ...      ...             ...
# 3364836      3364836    27507     29671      -1  4693921               A
# 3364837      3364837    27507     29671      -1  4741596               A
# 3364838      3364838    27507     29671      -1  4754269               A
# 3364839      3364839    27507     29671      -1  4806294               A
# 3364840      3364840    27507     29671      -1  5084179               A
#
#         derived_state       date
# 0                   A 2024-06-06
# 1                   G 2024-06-06
# 2                   A 2024-06-01
# 3                   A 2024-06-01
# 4                   A 2024-06-01
# ...               ...        ...
# 3364836             T 2024-06-06
# 3364837             T 2024-06-06
# 3364838             T 2024-06-06
# 3364839             G 2024-06-06
# 3364840             G 2024-06-06
#
# [3364841 rows x 8 columns]

# %%
ts_usher.metadata
# Out:
# {'time_zero_date': '2024-06-06'}

# %% [markdown]
# # Intersection sc2ts ARG
#
# Subset of main sc2ts ARG subset to the intersection of samples and sites common to sc2ts and UShER. Internal nodes have **not** been dated by tsdate and so will likely differ from the node dates on the main ARG.

# %%
ts_sc2ts_inter = tszip.load(sc2ts_viridian_inter)
ts_sc2ts_inter
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>466</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>days</td></tr>
#                             <tr><td>Sample Nodes</td><td>2 827 813</td></tr>
#                             <tr><td>Total Size</td><td>336.2 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#                     time_zero_date: 2024-06-06<br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>3 096 523</td>
#                 <td>94.5 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>2 416 521</td>
#                 <td>85.3 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>3 095 327</td>
#                 <td>129.9 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>1 604</td>
#                 <td>2.2 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>27 505</td>
#                 <td>671.5 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>25 May, 2026 at 11:01:26 AM</td>
#                     <td>tskit</td>
#                     <td>1.0.2</td>
#                     <td>delete_sites</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: tskit<br/>version: 1.0.2<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     command: delete_sites<br/>TODO: add parameters<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: cloudcomp100.hpc.in.bmrc.ox.ac<br/>.uk<br/>release: 4.18.0-553.123.1.el8_10.x86_64<br/>version: #1 SMP Tue May 5 15:46:59 UTC<br/>2026<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">kastore:</span>
#                 <details >
#                     <summary>dict</summary>
#                     version: 2.1.2<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#
#                         </details>

# %%
sc2ts.node_data(ts_sc2ts_inter)
# Out:
#                 sample_id  node_id  is_sample  is_recombinant  num_mutations  \
# 0             SRR11772659        0       True           False              1
# 1             SRR11397727        1       True           False              0
# 2             SRR11597198        2       True           False              0
# 3             SRR11597221        3       True           False              0
# 4             SRR11597143        4       True           False              2
# ...                   ...      ...        ...             ...            ...
# 3095322                    3095322      False           False              1
# 3095323                    3095323      False           False              1
# 3095324                    3095324      False           False              1
# 3095325   Wuhan/Hu-1/2019  3095325      False           False              0
# 3095326  Vestigial_ignore  3095326      False           False              0
#
#               date
# 0       2020-01-19
# 1       2020-01-24
# 2       2020-01-25
# 3       2020-01-25
# 4       2020-01-28
# ...            ...
# 3095322 2020-01-07
# 3095323 2020-01-04
# 3095324 2020-01-01
# 3095325 2019-12-26
# 3095326 2019-12-25
#
# [3095327 rows x 6 columns]

# %%
sc2ts.mutation_data(ts_sc2ts_inter)
# Out:
#          mutation_id  site_id  position  parent     node inherited_state  \
# 0                  0        1       269      -1     5525               G
# 1                  1        1       269      -1  3074076               G
# 2                  2        1       269      -1    77772               G
# 3                  3        1       269      -1    96256               G
# 4                  4        1       269      -1   101271               G
# ...              ...      ...       ...     ...      ...             ...
# 2416516      2416516    27504     29671      -1  1391696               A
# 2416517      2416517    27504     29671      -1  2831887               A
# 2416518      2416518    27504     29671      -1  1443072               A
# 2416519      2416519    27504     29671      -1  1445755               A
# 2416520      2416520    27504     29671      -1  2830624               A
#
#         derived_state       date
# 0                   A 2020-04-08
# 1                   A 2021-01-04
# 2                   A 2021-01-04
# 3                   A 2021-01-24
# 4                   A 2021-01-27
# ...               ...        ...
# 2416516             G 2023-02-12
# 2416517             T 2023-10-13
# 2416518             T 2023-10-24
# 2416519             T 2023-11-08
# 2416520             T 2023-11-17
#
# [2416521 rows x 8 columns]

# %%
ts_sc2ts.metadata
# Out:
# {'time_zero_date': '2024-06-06'}

# %% [markdown]
# # Intersection UShER ARG
#
# Subset of main UShER ARG subset to the intersection of samples and sites common to both. Internal nodes have been dated by tsdate.

# %%
ts_usher_inter =tszip.load(usher_viridian_inter)
ts_usher_inter
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>1</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>days</td></tr>
#                             <tr><td>Sample Nodes</td><td>2 827 813</td></tr>
#                             <tr><td>Total Size</td><td>370.0 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">sc2ts:</span>
#                 <details >
#                     <summary>dict</summary>
#                     date: 2024-06-06<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>3 405 806</td>
#                 <td>103.9 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>2 273 199</td>
#                 <td>80.2 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>3 405 807</td>
#                 <td>159.2 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>6</td>
#                 <td>3.6 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>27 505</td>
#                 <td>671.5 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>25 May, 2026 at 02:33:58 PM</td>
#                     <td>tsdate</td>
#                     <td>0.2.3</td>
#                     <td>variational_gamma</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: tsdate<br/>version: 0.2.3<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     mutation_rate: 8.849201267435188e-07<br/>recombination_rate: None<br/>time_units: days<br/>progress: True<br/>population_size: None<br/>eps: 1e-10<br/>max_iterations: 1<br/>max_shape: 1000<br/>rescaling_intervals: 0<br/>rescaling_iterations: 5<br/>match_segregating_sites: False<br/>regularise_roots: True<br/>singletons_phased: True<br/>command: variational_gamma<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: cloudcomp100.hpc.in.bmrc.ox.ac<br/>.uk<br/>release: 4.18.0-553.123.1.el8_10.x86_64<br/>version: #1 SMP Tue May 5 15:46:59 UTC<br/>2026<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >

# %%
sc2ts.node_data(ts_usher_inter)
# Out:
#           Date_tree    sample_id  node_id  is_sample  is_recombinant  \
# 0        2020-01-19  SRR11772659        0       True           False
# 1        2020-01-24  SRR11397727        1       True           False
# 2        2020-01-25  SRR11597198        2       True           False
# 3        2020-01-25  SRR11597221        3       True           False
# 4        2020-01-28  SRR11597143        4       True           False
# ...             ...          ...      ...        ...             ...
# 3405802                node_1696  3405802      False           False
# 3405803                node_1695  3405803      False           False
# 3405804                node_1694  3405804      False           False
# 3405805                node_1693  3405805      False           False
# 3405806                   node_1  3405806      False           False
#
#          num_mutations
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    2
# ...                ...
# 3405802              1
# 3405803              1
# 3405804              0
# 3405805              1
# 3405806              0
#
# [3405807 rows x 6 columns]

# %%
sc2ts.mutation_data(ts_usher_inter)
# Out:
#          mutation_id  site_id  position  parent     node inherited_state  \
# 0                  0        1       269      -1     5525               G
# 1                  1        1       269      -1  3378998               G
# 2                  2        1       269      -1    96256               G
# 3                  3        1       269      -1    77772               G
# 4                  4        1       269      -1  3369665               G
# ...              ...      ...       ...     ...      ...             ...
# 2273194      2273194    27504     29671      -1  1367287               A
# 2273195      2273195    27504     29671      -1  1445755               A
# 2273196      2273196    27504     29671      -1  3089870               A
# 2273197      2273197    27504     29671      -1  1443072               A
# 2273198      2273198    27504     29671      -1  3080955               A
#
#         derived_state
# 0                   A
# 1                   A
# 2                   A
# 3                   A
# 4                   A
# ...               ...
# 2273194             T
# 2273195             T
# 2273196             T
# 2273197             T
# 2273198             T
#
# [2273199 rows x 7 columns]

# %%
ts_usher_inter.metadata
# Out:
# {'sc2ts': {'date': '2024-06-06'}}
