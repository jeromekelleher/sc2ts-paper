# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing', '/gpfs3/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/bin', '/apps/eb/el8/2023a/epyc/software/Python/3.11.3-GCCcore-12.3.0/easybuild/python', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/lib-dynload', '/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/src/pangonet/src', '/users/kelleher/sbk774/.cache/snakemake/snakemake/source-cache/snakemake-runtime-cache/tmp1460z01a/file/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks']);import pickle;snakemake = pickle.loads(b'\x80\x04\x95u\x04\x00\x00\x00\x00\x00\x00\x8c\x16snakemake.iocontainers\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94h\x00\x8c\nInputFiles\x94\x93\x94)\x81\x94\x8c6sc2ts_v2_2024-06-06_pr_pp_mp_aph_bps_pango_dated.trees\x94a}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x0fh\x00\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbub\x8c\x06output\x94h\x00\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8cDsc2ts_v2_2024-06-06_pr_pp_mp_aph_bps_pango_dated_deletion_events.csv\x94a}\x94(h\x0b}\x94h\r]\x94(h\x0fh\x10eh\x0fh\x12)\x81\x94}\x94h\x15h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbub\x8c\r_params_store\x94h\x00\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0b}\x94h\r]\x94(h\x0fh\x10eh\x0fh\x12)\x81\x94}\x94h\x15h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x00\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c0sc2ts_v2_2024-06-06_pr_pp_mp_aph_bps_pango_dated\x94a}\x94(h\x0b}\x94\x8c\x0bDELR_PREFIX\x94K\x00N\x86\x94sh\r]\x94(h\x0fh\x10eh\x0fh\x12)\x81\x94}\x94h\x15h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbh8h5ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x00\x8c\x0cResourceList\x94\x93\x94)\x81\x94(\x8c\x04/tmp\x94K\x01K\x01e}\x94(h\x0b}\x94(\x8c\x06tmpdir\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06_cores\x94K\x02N\x86\x94uh\r]\x94(h\x0fh\x10eh\x0fh\x12)\x81\x94}\x94h\x15h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbhGhDhIK\x01hKK\x01ub\x8c\x03log\x94h\x00\x8c\x03Log\x94\x93\x94)\x81\x94\x8cKlogs/sc2ts_v2_2024-06-06_pr_pp_mp_aph_bps_pango_dated_deletion-report.ipynb\x94a}\x94(h\x0b}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\r]\x94(h\x0fh\x10eh\x0fh\x12)\x81\x94}\x94h\x15h\x0fsbh\x10h\x12)\x81\x94}\x94h\x15h\x10sbhYhVub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\x0fdeletion_report\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cY/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks\x94ub.');from snakemake.logging import logger;from snakemake.iocontainers import Snakemake;import os; os.chdir(r'/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing');
######## snakemake preamble end #########

# %%
import tszip
import sc2ts.debug as sd
import pandas as pd

# %%
ts = tszip.load(snakemake.input[0])
ts
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
# ...

# %%
ti = sd.ArgInfo(ts, show_progress=False)
ti
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#     <tr>
#       <th>property</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>latest_sample</th>
#       <td>2024-06-05</td>
#     </tr>
#     <tr>
#       <th>samples</th>
#       <td>2834524</td>
#     </tr>
#     <tr>
#       <th>nodes</th>
#       <td>3104348</td>
#     </tr>
#     <tr>
#       <th>exact_matches</th>
#       <td>1362818</td>
#     </tr>
#     <tr>
#       <th>mc_nodes</th>
#       <td>104679</td>
#     </tr>
#     <tr>
#       <th>pr_nodes</th>
#       <td>54736</td>
#     </tr>
#     <tr>
#       <th>re_nodes</th>
# ...

# %%
ti.plot_mutations_per_node_distribution();

# %%
ti.plot_mutations_per_site_distribution();

# %%
ti.plot_mutations_per_site(annotate_threshold=0.65);

# %%
ti.plot_mutations_per_site(annotate_threshold=0.10, select=ti.mutations_is_reversion);

# %%
ti.plot_deletion_overlaps(annotate_threshold=0.1);

# %%
df = ti.deletions_summary()
df
# Out:
#        start     node  length  max_inheritors  min_inheritors
# 0        686     1086       9               1               1
# 1        686     1779       9               2               2
# 2        686     2801       9               1               1
# 3        686     4089       9               6               6
# 4        686     5152       9               1               1
# ...      ...      ...     ...             ...             ...
# 14191  28370  3096272       1               2               2
# 14192  28370  3097006       1               9               9
# 14193  28370  3099616       1               4               4
# 14194  28370  3099840       1               8               8
# 14195  28370  3101414       1               5               5
#
# [14196 rows x 5 columns]

# %%
df.to_csv(snakemake.output[0]);

# %%
df.length.value_counts()
# Out:
# length
# 9     8067
# 3     3483
# 6     1051
# 1      578
# 2      550
# 4      204
# 7      133
# 5      107
# 8       22
# 12       1
# Name: count, dtype: int64

# %%
dfl = df[df.max_inheritors > 100].sort_values("max_inheritors")
dfl
# Out:
#        start     node  length  max_inheritors  min_inheritors
# 7624     686  3099867       9             101             101
# 12902  21991  3102153       2             101             101
# 13749  22194  1576305       3             101             101
# 13047  21993  3101950       1             101             101
# 12718  21991  3096854       3             102             102
# ...      ...      ...     ...             ...             ...
# 8545   28362  1731105       9         1113386         1086902
# 8541   11288  1731105       4         1113396         1113374
# 13288  22029   209172       6         1207910         1207438
# 13886  28248   233509       6         1211612         1211247
# 14147  28271  1731122       1         1215461         1215461
#
# [121 rows x 5 columns]

# %%
dfl.length.value_counts()
# Out:
# length
# 3    40
# 9    34
# 6    20
# 1    16
# 2     7
# 5     2
# 7     1
# 4     1
# Name: count, dtype: int64

# %%
df.sort_values("max_inheritors").tail(20)
# Out:
#        start     node  length  max_inheritors  min_inheritors
# 9207   22194  1701949       3           19830           19830
# 7512     686  3099153       9           25952           25904
# 11511  21991  1576422       3           78810           78801
# 9052   21765  1269164       6          248753          248689
# 8517   21991    90456       3          298088          297374
# 8515   11288    90456       9          299675          299669
# 8516   21765    90456       6          299701          296723
# 8518   28271    90456       1          299713          299713
# 8544   22194  1731105       3          323398          323172
# 8543   21987  1731105       9          351416          351177
# 8542   21765  1731105       6          351444          351271
# 8236   11283   924054       5          351664          351662
# 8235    6513   924054       3          352637          352630
# 8614   21633   891729       9          761663          758333
# ...
