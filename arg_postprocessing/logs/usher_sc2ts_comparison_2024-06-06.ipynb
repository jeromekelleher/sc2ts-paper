# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing', '/gpfs3/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/bin', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/lib-dynload', '/users/kelleher/sbk774/.local/lib/python3.12/site-packages', '/well/kelleher/users/sbk774/conda/skylake/envs/sc2ts/lib/python3.12/site-packages', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/src/pangonet/src', '/users/kelleher/sbk774/.cache/snakemake/snakemake/source-cache/snakemake-runtime-cache/tmpaipjd53a/file/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks', '/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks']);import pickle;snakemake = pickle.loads(b"\x80\x04\x95\xa5\x04\x00\x00\x00\x00\x00\x00\x8c\x16snakemake.iocontainers\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94h\x00\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c#usher_2024-06-06_intersection.trees\x94\x8c'usher_2024-06-06_intersection_asp.trees\x94\x8c%usher_2024-06-06_intersection_asp.csv\x94\x8c#sc2ts_2024-06-06_intersection.trees\x94\x8c'sc2ts_2024-06-06_intersection_asp.trees\x94\x8c%sc2ts_2024-06-06_intersection_asp.csv\x94e}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x14h\x00\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbub\x8c\x06output\x94h\x00\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94}\x94(h\x10}\x94h\x12]\x94(h\x14h\x15eh\x14h\x17)\x81\x94}\x94h\x1ah\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbub\x8c\r_params_store\x94h\x00\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x10}\x94h\x12]\x94(h\x14h\x15eh\x14h\x17)\x81\x94}\x94h\x1ah\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x00\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c\n2024-06-06\x94a}\x94(h\x10}\x94\x8c\x04DATE\x94K\x00N\x86\x94sh\x12]\x94(h\x14h\x15eh\x14h\x17)\x81\x94}\x94h\x1ah\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sb\x8c\x04DATE\x94h9ub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x00\x8c\x0cResourceList\x94\x93\x94)\x81\x94(\x8c\x04/tmp\x94K\x01K\x01e}\x94(h\x10}\x94(\x8c\x06tmpdir\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06_cores\x94K\x02N\x86\x94uh\x12]\x94(h\x14h\x15eh\x14h\x17)\x81\x94}\x94h\x1ah\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbhLhIhNK\x01hPK\x01ub\x8c\x03log\x94h\x00\x8c\x03Log\x94\x93\x94)\x81\x94\x8c,logs/usher_sc2ts_comparison_2024-06-06.ipynb\x94a}\x94(h\x10}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x12]\x94(h\x14h\x15eh\x14h\x17)\x81\x94}\x94h\x1ah\x14sbh\x15h\x17)\x81\x94}\x94h\x1ah\x15sbh^h[ub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\x16usher_sc2ts_comparison\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cY/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing/notebooks\x94ub.");from snakemake.logging import logger;from snakemake.iocontainers import Snakemake;import os; os.chdir(r'/gpfs3/well/kelleher/users/nrn539/sc2ts_revision/sc2ts-paper/arg_postprocessing');
######## snakemake preamble end #########

# %%
import pandas as pd
import sc2ts
import tszip
import numpy as np
import matplotlib.pyplot as plt

# %%
tsu = tszip.load(snakemake.input[0])
tsup = tszip.load(snakemake.input[1])
dfup = pd.read_csv(snakemake.input[2], index_col=0)

# %%
tss = tszip.load(snakemake.input[3])
tssp = tszip.load(snakemake.input[4])
dfsp = pd.read_csv(snakemake.input[5], index_col=0)

# %% [markdown]
# # Base ARGs
#
# Comparison of the two base ARGs (tsu is Usher, tss is sc2ts)

# %%
tsu
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
# ...

# %%
tss
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
# ...

# %%
data = []
for name, ts in [("usher", tsu), ("sc2ts", tss)]:
    data.append({
        "name": name,
        "trees": ts.num_trees,
        "nodes": ts.num_nodes,
        "edges": ts.num_edges,
        "mutations": ts.num_mutations,
        "samples": ts.num_samples,
    })
pd.DataFrame(data)
# Out:
#     name  trees    nodes    edges  mutations  samples
# 0  usher      1  3754905  3754904    2552470  3121437
# 1  sc2ts    509  3402834  3404199    2605865  3121437

# %%
assert tsu.reference_sequence.metadata == tss.reference_sequence.metadata
assert tsu.reference_sequence.data == tss.reference_sequence.data

# %%
diff = tss.num_mutations - tsu.num_mutations
diff
# Out:
# 53395

# %%
f"Difference in mutations = {diff /  tss.num_mutations:.2%}"
# Out:
# 'Difference in mutations = 2.05%'

# %% [markdown]
# The differences are not uniform along the genome, with sc2ts having significantly more mutations at a handful of positions

# %%
_, ax = plt.subplots(1, figsize=(16, 4))
ax.plot(dfup.site, dfsp.old - dfup.old) 
ax.set_ylabel("Difference between mutation counts")
# Out:
# Text(0, 0.5, 'Difference between mutation counts')

# %%
diff = tsu.num_nodes - tss.num_nodes
diff
# Out:
# 352071

# %%
f"Difference in nodes = {diff /  tsu.num_nodes:.2%}"
# Out:
# 'Difference in nodes = 9.38%'

# %% [markdown]
# There is a significant difference in the number of nodes, although this is at least partially explained by sc2ts allowing samples to be internal:

# %%
tree = tsu.first()
np.sum(tree.num_children_array[tsu.samples()] > 0)
# Out:
# np.int64(0)

# %%
tree = tss.first()
np.sum(tree.num_children_array[tss.samples()] > 0)
# Out:
# np.int64(368638)

# %% [markdown]
# # All sites parsimony ARGs
#
# Comparison of the ARGs we get when we map all the deletions back on (only changes mutations)

# %%
tsup.num_mutations
# Out:
# 23598379

# %%
tssp.num_mutations
# Out:
# 29792313

# %%
diff = tssp.num_mutations - tsup.num_mutations
diff
# Out:
# 6193934

# %%
f"Difference in mutations = {diff /  tssp.num_mutations:.2%}"
# Out:
# 'Difference in mutations = 20.79%'

# %% [markdown]
# There is a significant difference between the two - what is this driven by? Let's look at the parsimony reports

# %%
dfup
# Out:
#         site  old  new  intersection
# 0          1    0    1             0
# 1          2    0    1             0
# 2          3    0    1             0
# 3          4    0    1             0
# 4          5    0    1             0
# ...      ...  ...  ...           ...
# 29898  29899    0    1             0
# 29899  29900    0    1             0
# 29900  29901    0    1             0
# 29901  29902    0    1             0
# 29902  29903    0    1             0
#
# [29903 rows x 4 columns]

# %%
dfsp
# Out:
#         site  old  new  intersection
# 0          1    0    1             0
# 1          2    0    1             0
# 2          3    0    1             0
# 3          4    0    1             0
# 4          5    0    1             0
# ...      ...  ...  ...           ...
# 29898  29899    0    1             0
# 29899  29900    0    1             0
# 29900  29901    0    1             0
# 29901  29902    0    1             0
# 29902  29903    0    1             0
#
# [29903 rows x 4 columns]

# %%
data = []
for name, df in [("sc2ts", dfsp), ("usher", dfup)]:
    data.append({
        "name": name,
        "identical": np.sum(df.old == df.new),
        "exact_inter": np.sum(df.old == df.intersection),
        "exact_inter10": np.sum((df.old == df.intersection) & (df.new - df.old < 10)),
        "exact_inter100": np.sum((df.old == df.intersection) & (df.new - df.old < 100)),
    })
pd.DataFrame(data)
# Out:
#     name  identical  exact_inter  exact_inter10  exact_inter100
# 0  sc2ts      15146        26268          19991           22800
# 1  usher      14831        26083          20153           22925

# %% [markdown]
# A large majority of the sites are identical before and after remapping with parsimony, and about 25k sites recapture the existing mutations exactly with small number of additional mutations.
#
# The differences seem to be from a small number of sites doing very badly. If we plot the number of remapped mutations in sc2ts vs usher along the genome.

# %%
_, ax = plt.subplots(1, figsize=(16, 4))
ax.plot(dfup.site, dfsp.new - dfup.new) 
ax.set_ylabel("Difference between remapped mutation counts")
ax.set_ylim((-2000, 2000));

# %% [markdown]
# Sc2ts seems to do particularly badly in the righthand flank, which accounts for a large fraction of the excess mutations

# %%
dfsp[dfsp.site > 29600]
# Out:
#         site  old    new  intersection
# 29600  29601    4  17079             4
# 29601  29602   17  17110            16
# 29602  29603    8  17110             8
# 29603  29604   57  17172            57
# 29604  29605    3  17131             3
# ...      ...  ...    ...           ...
# 29898  29899    0      1             0
# 29899  29900    0      1             0
# 29900  29901    0      1             0
# 29901  29902    0      1             0
# 29902  29903    0      1             0
#
# [303 rows x 4 columns]

# %%
dfsp[dfsp.site > 29600].new.sum() - dfup[dfup.site > 29600].new.sum()
# Out:
# np.int64(2492160)

# %% [markdown]
# Usher seems to do badly in one particular place:

# %%
diffs = dfsp.new - dfup.new
dfup[diffs < -1000]
# Out:
#         site  old    new  intersection
# 21609  21610    2   3537             2
# 21611  21612    0   3308             0
# 21612  21613    0   3336             0
# 21614  21615    1   3403             1
# 21615  21616    0   3267             0
# 21616  21617    1   3694             1
# 21618  21619    0   3309             0
# 21619  21620    0   3320             0
# 21620  21621   61   4445             0
# 21623  21624    6   4670             5
# 21624  21625    0   3654             0
# 21625  21626    0   3600             0
# 21626  21627    6   4794             5
# 21631  21632    1   3385             1
# 21632  21633  120   3444           119
# 21633  21634   21   3188            21
# 21635  21636  196   3358           196
# 21636  21637    0   3625             0
# 21637  21638  432   3597           432
# 21638  21639    1   3704             1
# 21639  21640    0   3229             0
# 21640  21641    1   4085             1
# 22193  22194  285  18034           243
# ...
