# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/home/jk/miniconda3/envs/snakemake/lib/python3.12/site-packages', '/scratch/jk/work/github/sc2ts-paper/arg_postprocessing', '/home/jk/miniconda3/envs/snakemake/bin', '/home/jk/miniconda3/envs/snakemake/lib/python3.12', '/home/jk/miniconda3/envs/snakemake/lib/python3.12/lib-dynload', '/home/jk/miniconda3/envs/snakemake/lib/python3.12/site-packages', '/home/jk/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpusl6gp_7/file/scratch/jk/work/github/sc2ts-paper/arg_postprocessing/notebooks', '/scratch/jk/work/github/sc2ts-paper/arg_postprocessing/notebooks']);import pickle;from snakemake import script;script.snakemake = pickle.loads(b"\x80\x04\x95\xa3\x04\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c>sc2ts_v1_2023-02-21_pp_dated_remapped_bps_pango_mmps.trees.tsz\x94\x8c usher_v1_2024-06-06_mm.trees.tsz\x94\x8c'sc2ts_2023-02-21_intersection.trees.tsz\x94\x8c-usher_2023-02-21_intersection_ds_di.trees.tsz\x94e}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x13h\x06\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x13sbh\x14h\x16)\x81\x94}\x94h\x19h\x14sbub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c\x1bsc2ts_viridian_v1.trees.tsz\x94\x8c\x1busher_viridian_v1.trees.tsz\x94\x8c!sc2ts_viridian_inter_v1.trees.tsz\x94\x8c!usher_viridian_inter_v1.trees.tsz\x94e}\x94(h\x0f}\x94h\x11]\x94(h\x13h\x14eh\x13h\x16)\x81\x94}\x94h\x19h\x13sbh\x14h\x16)\x81\x94}\x94h\x19h\x14sbub\x8c\r_params_store\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x11]\x94(h\x13h\x14eh\x13h\x16)\x81\x94}\x94h\x19h\x13sbh\x14h\x16)\x81\x94}\x94h\x19h\x14sbub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x11]\x94(h\x13h\x14eh\x13h\x16)\x81\x94}\x94h\x19h\x13sbh\x14h\x16)\x81\x94}\x94h\x19h\x14sbub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0f}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x11]\x94(h\x13h\x14eh\x13h\x16)\x81\x94}\x94h\x19h\x13sbh\x14h\x16)\x81\x94}\x94h\x19h\x14sbhKK\x01hMK\x01hOhHub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c\x1blogs/final_arg_report.ipynb\x94a}\x94(h\x0f}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x11]\x94(h\x13h\x14eh\x13h\x16)\x81\x94}\x94h\x19h\x13sbh\x14h\x16)\x81\x94}\x94h\x19h\x14sbh]hZub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\nfinal_args\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c@/scratch/jk/work/github/sc2ts-paper/arg_postprocessing/notebooks\x94ub.");del script;from snakemake.logging import logger;from snakemake.script import snakemake;import os; os.chdir(r'/scratch/jk/work/github/sc2ts-paper/arg_postprocessing');
######## snakemake preamble end #########

# %%
import sc2ts
import tszip
import shutil

# %%
assert len(snakemake.input) == len(snakemake.output) == 4
for fin, fout in zip(snakemake.input, snakemake.output):
    shutil.copy(fin, fout)

# %% [markdown]
# # Main sc2ts ARG
#
# Built from Viridian data up to 2023-02-21. Internal nodes have been dated using tsdate, and contains deletions and highly homoplasic sites post-hoc mapped on by parsimony.

# %%
ts_sc2ts = tszip.load("sc2ts_viridian_v1.trees.tsz")
ts_sc2ts
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>348</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>days</td></tr>
#                             <tr><td>Sample Nodes</td><td>2 482 157</td></tr>
#                             <tr><td>Total Size</td><td>427.1 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#                     time_zero_date: 2023-02-21<br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>2 689 981</td>
#                 <td>82.1 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>3 023 541</td>
#                 <td>106.7 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>2 689 054</td>
#                 <td>215.4 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>1 133</td>
#                 <td>1.7 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>29 893</td>
#                 <td>729.8 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>27 June, 2025 at 10:35:46 PM</td>
#                     <td>sc2ts</td>
#                     <td>0.0.4.dev644+gf671a5e</td>
#                     <td>minimise_metadata</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: sc2ts<br/>version: 0.0.4.dev644+gf671a5e<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     command: minimise_metadata<br/>
#             <div>
#                 <span class="tskit-details-label">field_mapping:</span>
#                 <details >
#                     <summary>dict</summary>
#                     strain: sample_id<br/>pango: pango<br/>scorpio: scorpio<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: holly<br/>release: 5.10.0-24-amd64<br/>version: #1 SMP Debian 5.10.179-5<br/>(2023-08-08)<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">kastore:</span>
#                 <details >
#                     <summary>dict</summary>
#                     version: 2.1.1<br/>
#                 </detail

# %%
sc2ts.node_data(ts_sc2ts)
# Out:
#            pango         sample_id                 scorpio  node_id  \
# 0              B  Vestigial_ignore                       .        0
# 1              B   Wuhan/Hu-1/2019                       .        1
# 2              A       SRR11772659                       .        2
# 3              B       SRR11397727                       .        3
# 4              B       SRR11397730                       .        4
# ...          ...               ...                     ...      ...
# 2689049   AY.103                    Delta (B.1.617.2-like)  2689049
# 2689050   BA.2.9                       Omicron (BA.2-like)  2689050
# 2689051     AY.4                         Delta (AY.4-like)  2689051
# 2689052    AY.44                    Delta (B.1.617.2-like)  2689052
# 2689053  B.1.561                                         .  2689053
#
#          is_sample  is_recombinant  num_mutations  max_descendant_samples  \
# 0            False           False              0                       0
# 1            False           False              0                 2482157
# 2             True           False              1                     255
# 3             True           False              0                       1
# 4             True           False              0                       1
# ...            ...             ...            ...                     ...
# 2689049      False           False              1                       3
# 2689050      False           False              3                       2
# 2689051      False           False              1                       3
# 2689052      False           False              1                      24
# 2689053      False           False              1                      44
#
#               date
# 0       2019-11-17
# 1       2019-12-26
# 2       2020-01-19
# 3       2020-01-24
# 4       2020-01-24
# ...            ...
# 2689049 2021-11-11
# 2689050 2022-03-04
# 2689051 2021-09-01
# 2689052 2021-10-15
# 2689053 2020-10-08
#
# [2689054 rows x 9 columns]

# %%
sc2ts.mutation_data(ts_sc2ts)
# Out:
#          mutation_id  position  parent     node inherited_state derived_state  \
# 0                  0        25      -1   644280               T             A
# 1                  1        38      -1    12915               A             G
# 2                  2        43      -1   344292               T             A
# 3                  3        43      -1   427855               T             C
# 4                  4        43      -1   670767               T             C
# ...              ...       ...     ...      ...             ...           ...
# 3023536      3023536     29850      -1   691821               A             G
# 3023537      3023537     29850      -1   719257               A             G
# 3023538      3023538     29850      -1   952268               A             G
# 3023539      3023539     29850      -1  1129360               A             G
# 3023540      3023540     29850      -1  1112507               A             G
#
#         date  num_descendants  num_inheritors
# 0        NaT                1               1
# 1        NaT                1               1
# 2        NaT                3               3
# 3        NaT                2               2
# 4        NaT                2               2
# ...      ...              ...             ...
# 3023536  NaT                1               1
# 3023537  NaT                2               2
# 3023538  NaT                5               5
# 3023539  NaT                1               1
# 3023540  NaT                3               3
#
# [3023541 rows x 9 columns]

# %%
ts_sc2ts.metadata
# Out:
# {'time_zero_date': '2023-02-21'}

# %% [markdown]
# # Main UShER tree
#
# Translation of the Viridian UShER tree to tskit format. Time units are uncalibrated and branch-lengths are not meaningful.

# %%
ts_usher = tszip.load("usher_viridian_v1.trees.tsz")
ts_usher
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>1</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>uncalibrated</td></tr>
#                             <tr><td>Sample Nodes</td><td>4 471 579</td></tr>
#                             <tr><td>Total Size</td><td>522.1 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#                     time_zero_date: 2024-06-06<br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>5 345 018</td>
#                 <td>163.1 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>3 364 841</td>
#                 <td>118.7 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>5 345 019</td>
#                 <td>198.8 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>2</td>
#                 <td>1.1 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>27 508</td>
#                 <td>671.6 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>06 July, 2025 at 04:19:50 PM</td>
#                     <td>sc2ts</td>
#                     <td>0.0.4.dev652+gff050ea</td>
#                     <td>minimise_metadata</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: sc2ts<br/>version: 0.0.4.dev652+gff050ea<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     command: minimise_metadata<br/>
#             <div>
#                 <span class="tskit-details-label">field_mapping:</span>
#                 <details >
#                     <summary>dict</summary>
#                     strain: sample_id<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: holly<br/>release: 5.10.0-24-amd64<br/>version: #1 SMP Debian 5.10.179-5<br/>(2023-08-08)<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">kastore:</span>
#                 <details >
#                     <summary>dict</summary>
#                     version: 2.1.1<br/>
#                 </details>
#             </div>
#             <

# %%
sc2ts.node_data(ts_usher)
# Out:
#            sample_id  node_id  is_sample  is_recombinant  num_mutations  \
# 0         ERR4085584        0       True           False              0
# 1         ERR4086315        1       True           False              0
# 2         ERR4091746        2       True           False              0
# 3         ERR4165155        3       True           False              0
# 4         ERR4204267        4       True           False              0
# ...              ...      ...        ...             ...            ...
# 5345014  SRR21886505  5345014       True           False              5
# 5345015  node_763111  5345015      False           False              1
# 5345016  SRR21635465  5345016       True           False              0
# 5345017  node_763112  5345017      False           False              1
# 5345018  SRR21795271  5345018       True           False              0
#
#          max_descendant_samples       date
# 0                             1 2024-06-06
# 1                             1 2024-06-06
# 2                             1 2024-06-06
# 3                             1 2024-06-06
# 4                             1 2024-06-06
# ...                         ...        ...
# 5345014                       1 2024-06-06
# 5345015                       3 2024-06-04
# 5345016                       1 2024-06-06
# 5345017                       2 2024-06-05
# 5345018                       1 2024-06-06
#
# [5345019 rows x 7 columns]

# %%
sc2ts.mutation_data(ts_usher)
# Out:
#          mutation_id  position  parent     node inherited_state derived_state  \
# 0                  0       267      -1  1235535               T             A
# 1                  1       267      -1  5297533               T             G
# 2                  2       269      -1   246856               G             A
# 3                  3       269      -1  2677518               G             A
# 4                  4       269      -1  4780608               G             A
# ...              ...       ...     ...      ...             ...           ...
# 3364836      3364836     29671      -1  4571321               A             G
# 3364837      3364837     29671      -1  4525231               A             T
# 3364838      3364838     29671      -1  4622571               A             G
# 3364839      3364839     29671      -1  4520611               A             T
# 3364840      3364840     29671      -1  2532777               A             G
#
#               date  num_descendants  num_inheritors
# 0       2024-06-06                1               1
# 1       2024-06-06                1               1
# 2       2024-06-01               12              12
# 3       2024-06-01               75              75
# 4       2024-06-01               26              26
# ...            ...              ...             ...
# 3364836 2024-06-06                1               1
# 3364837 2024-06-06                1               1
# 3364838 2024-06-06                1               1
# 3364839 2024-06-06                1               1
# 3364840 2024-06-06                1               1
#
# [3364841 rows x 9 columns]

# %%
ts_usher.metadata
# Out:
# {'time_zero_date': '2024-06-06'}

# %% [markdown]
# # Intersection sc2ts ARG
#
# Subset of main sc2ts ARG subset to the intersection of samples and sites common to both. Internal nodes have **not** been dated by tsdate and so will likely differ from the node dates on the main ARG.

# %%
ts_sc2ts_inter = tszip.load("sc2ts_viridian_inter_v1.trees.tsz")
ts_sc2ts_inter
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>348</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>days</td></tr>
#                             <tr><td>Sample Nodes</td><td>2 475 418</td></tr>
#                             <tr><td>Total Size</td><td>282.0 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#                     time_zero_date: 2023-02-21<br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>2 681 268</td>
#                 <td>81.8 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>1 838 924</td>
#                 <td>64.9 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>2 680 335</td>
#                 <td>112.5 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>1 132</td>
#                 <td>1.7 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>27 431</td>
#                 <td>669.7 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>06 July, 2025 at 04:21:35 PM</td>
#                     <td>tskit</td>
#                     <td>0.6.4</td>
#                     <td>delete_sites</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: tskit<br/>version: 0.6.4<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     command: delete_sites<br/>TODO: add parameters<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: holly<br/>release: 5.10.0-24-amd64<br/>version: #1 SMP Debian 5.10.179-5<br/>(2023-08-08)<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">kastore:</span>
#                 <details >
#                     <summary>dict</summary>
#                     version: 2.1.1<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#
#                         </details>
#                     </td>
#                 </tr>

# %%
sc2ts.node_data(ts_sc2ts_inter)
# Out:
#                 sample_id  node_id  is_sample  is_recombinant  num_mutations  \
# 0             SRR11772659        0       True           False              1
# 1             SRR11397727        1       True           False              0
# 2             SRR11597198        2       True           False              0
# 3             SRR11597221        3       True           False              0
# 4             SRR11597143        4       True           False              2
# ...                   ...      ...        ...             ...            ...
# 2680330                    2680330      False           False              1
# 2680331                    2680331      False           False              1
# 2680332                    2680332      False           False              1
# 2680333   Wuhan/Hu-1/2019  2680333      False           False              0
# 2680334  Vestigial_ignore  2680334      False           False              0
#
#          max_descendant_samples       date
# 0                           253 2020-01-19
# 1                             1 2020-01-24
# 2                             1 2020-01-25
# 3                             1 2020-01-25
# 4                             1 2020-01-28
# ...                         ...        ...
# 2680330                       6 2020-01-12
# 2680331                 2471064 2020-01-12
# 2680332                       2 2020-01-12
# 2680333                 2475418 2019-12-26
# 2680334                 2475418 2019-12-25
#
# [2680335 rows x 7 columns]

# %%
sc2ts.mutation_data(ts_sc2ts_inter)
# Out:
#          mutation_id  position  parent     node inherited_state derived_state  \
# 0                  0       269      -1  2664849               G             A
# 1                  1       269      -1    74546               G             A
# 2                  2       269      -1    97151               G             A
# 3                  3       269      -1    97236               G             A
# 4                  4       269      -1   114666               G             A
# ...              ...       ...     ...      ...             ...           ...
# 1838919      1838919     29671      -1  1100325               A             G
# 1838920      1838920     29671      -1  2493154               A             G
# 1838921      1838921     29671      -1  1113651               A             G
# 1838922      1838922     29671      -1  1167429               A             G
# 1838923      1838923     29671      -1  1203202               A             T
#
#               date  num_descendants  num_inheritors
# 0       2020-12-16               39              39
# 1       2021-01-04                1               1
# 2       2021-01-27                1               1
# 3       2021-01-27               10              10
# 4       2021-02-12               23              23
# ...            ...              ...             ...
# 1838919 2022-07-02                3               3
# 1838920 2022-07-08                2               2
# 1838921 2022-07-12                3               3
# 1838922 2022-09-10                1               1
# 1838923 2022-11-14                1               1
#
# [1838924 rows x 9 columns]

# %%
ts_sc2ts.metadata
# Out:
# {'time_zero_date': '2023-02-21'}

# %% [markdown]
# # Intersection sc2ts ARG
#
# Subset of main sc2ts ARG subset to the intersection of samples and sites common to both. Internal nodes have been dated by tsdate.

# %%
ts_usher_inter =tszip.load("usher_viridian_inter_v1.trees.tsz")
ts_usher_inter
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>1</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>days</td></tr>
#                             <tr><td>Sample Nodes</td><td>2 475 418</td></tr>
#                             <tr><td>Total Size</td><td>318.2 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">sc2ts:</span>
#                 <details >
#                     <summary>dict</summary>
#                     date: 2023-02-20<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>2 974 607</td>
#                 <td>90.8 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>1 843 132</td>
#                 <td>65.0 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>2 974 608</td>
#                 <td>139.0 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>6</td>
#                 <td>3.4 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>27 431</td>
#                 <td>669.7 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>06 July, 2025 at 05:17:52 PM</td>
#                     <td>tsdate</td>
#                     <td>0.2.3</td>
#                     <td>variational_gamma</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: tsdate<br/>version: 0.2.3<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     mutation_rate: 8.286637782252725e-07<br/>recombination_rate: None<br/>time_units: days<br/>progress: True<br/>population_size: None<br/>eps: 1e-10<br/>max_iterations: 1<br/>max_shape: 1000<br/>rescaling_intervals: 0<br/>rescaling_iterations: 5<br/>match_segregating_sites: False<br/>regularise_roots: True<br/>singletons_phased: True<br/>command: variational_gamma<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: holly<br/>release: 5.10.0-24-amd64<br/>version: #1 SMP Debian 5.10.179-5<br/>(2023-08-08)<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>

# %%
sc2ts.node_data(ts_usher_inter)
# Out:
#           Date_tree    sample_id  node_id  is_sample  is_recombinant  \
# 0        2020-01-19  SRR11772659        0       True           False
# 1        2020-01-24  SRR11397727        1       True           False
# 2        2020-01-25  SRR11597198        2       True           False
# 3        2020-01-25  SRR11597221        3       True           False
# 4        2020-01-28  SRR11597143        4       True           False
# ...             ...          ...      ...        ...             ...
# 2974603                node_1696  2974603      False           False
# 2974604                node_1695  2974604      False           False
# 2974605                node_1694  2974605      False           False
# 2974606                node_1693  2974606      False           False
# 2974607                   node_1  2974607      False           False
#
#          num_mutations  max_descendant_samples
# 0                    0                       1
# 1                    0                       1
# 2                    0                       1
# 3                    0                       1
# 4                    2                       1
# ...                ...                     ...
# 2974603              1                 2471054
# 2974604              1                 2471057
# 2974605              0                 2471060
# 2974606              1                 2471087
# 2974607              0                 2475418
#
# [2974608 rows x 7 columns]

# %%
sc2ts.mutation_data(ts_usher_inter)
# Out:
#          mutation_id  position  parent     node inherited_state derived_state  \
# 0                  0       269      -1  2950593               G             A
# 1                  1       269      -1    74546               G             A
# 2                  2       269      -1  2941538               G             A
# 3                  3       269      -1  2930168               G             A
# 4                  4       269      -1  2810634               G             A
# ...              ...       ...     ...      ...             ...           ...
# 1843127      1843127     29671      -1  1050450               A             G
# 1843128      1843128     29671      -1  2716802               A             G
# 1843129      1843129     29671      -1  2844868               A             G
# 1843130      1843130     29671      -1  2718613               A             G
# 1843131      1843131     29671      -1  1203202               A             T
#
#          num_descendants  num_inheritors
# 0                     39              39
# 1                      1               1
# 2                      9               9
# 3                     23              23
# 4                     10              10
# ...                  ...             ...
# 1843127                1               1
# 1843128                3               3
# 1843129                3               3
# 1843130                2               2
# 1843131                1               1
#
# [1843132 rows x 8 columns]

# %%
ts_usher_inter.metadata
# Out:
# {'sc2ts': {'date': '2023-02-20'}}
