# %% [markdown]
# Shift breakpoint interval coordinates
#
# This is a temporary solution. See this issue:
#
# https://github.com/jeromekelleher/sc2ts-paper/issues/364

# %%
import numpy as np
import pandas as pd
import tszip
import sc2ts

# %%
# Ts file with shifted breakpoint intervals.
ts_file = "../inference/v1-beta1_2023-02-21.pp.md.bpshift.ts.dated.il.tsz"
ts = tszip.decompress(ts_file)

# %%
ti = sc2ts.info.TreeInfo(ts)
ti
# Out:
# Counting descendants :   0%|          | 0/2689054 [00:00<?, ?it/s]
# Indexing metadata    :   0%|          | 0/2689054 [00:00<?, ?it/s]
# Classifying mutations:   0%|          | 0/1922947 [00:00<?, ?it/s]
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#     <tr>
#       <th>property</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>latest_sample</th>
#       <td>2023-02-20</td>
#     </tr>
#     <tr>
#       <th>samples</th>
#       <td>2482157</td>
#     </tr>
#     <tr>
#       <th>nodes</th>
#       <td>2689054</td>
#     </tr>
#     <tr>
#       <th>exact_matches</th>
#       <td>1252208</td>
#     </tr>
#     <tr>
#       <th>mc_nodes</th>
#       <td>73166</td>
#     </tr>
#     <tr>
#       <th>pr_nodes</th>
#       <td>40099</td>
#     </tr>
#     <tr>
#       <th>re_nodes</th>
#       <td>929</td>
#     </tr>
#     <tr>
#       <th>imr_nodes</th>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>mutations</th>
#       <td>1922947</td>
#     </tr>
#     <tr>
#       <th>recurrent</th>
#       <td>34493</td>
#     </tr>
#     <tr>
#       <th>reversions</th>
#       <td>29996</td>
#     </tr>
#     <tr>
#       <th>immediate_reversions</th>
#       <td>2938</td>
#     </tr>
#     <tr>
#       <th>private_mutations</th>
#       <td>1209866</td>
#     </tr>
#     <tr>
#       <th>transitions</th>
#       <td>1435218</td>
#     </tr>
#     <tr>
#       <th>transversions</th>
#       <td>469463</td>
#     </tr>
#     <tr>
#       <th>insertions</th>
#       <td>6223</td>
#     </tr>
#     <tr>
#       <th>deletions</th>
#       <td>12043</td>
#     </tr>
#     <tr>
#       <th>max_mutations_parents</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>nodes_with_zero_muts</th>
#       <td>1475707</td>
#     </tr>
#     <tr>
#       <th>sites_with_zero_muts</th>
#       <td>2894</td>
#     </tr>
#     <tr>
#       <th>max_mutations_per_site</th>
#       <td>1549</td>
#     </tr>
#     <tr>
#       <th>mean_mutations_per_site</th>
#       <td>64.521927</td>
#     </tr>
#     <tr>
#       <th>median_mutations_per_site</th>
#       <td>27.0</td>
#     </tr>
#     <tr>
#       <th>max_mutations_per_node</th>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>max_mutations_per_non_sample_node</th>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>max_missing_sites_per_sample</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>mean_missing_sites_per_sample</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>max_missing_samples_per_site</th>
#       <td>1229949</td>
#     </tr>
#     <tr>
#       <th>mean_missing_samples_per_site</th>
#       <td>8198.722478</td>
#     </tr>
#     <tr>
#       <th>max_deletion_sites_per_sample</th>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>mean_deletion_sites_per_sample</th>
#       <td>-1.0</td>
#     </tr>
#     <tr>
#       <th>max_deletion_samples_per_site</th>
#       <td>622989</td>
#     </tr>
#     <tr>
#       <th>mean_deletion_samples_per_site</th>
#       <td>1131.073013</td>
#     </tr>
#     <tr>
#       <th>max_samples_per_day</th>
#       <td>12592</td>
#     </tr>
#     <tr>
#       <th>mean_samples_per_day</th>
#       <td>2196.599115</td>
#     </tr>
#     <tr>
#       <th>sample_groups</th>
#       <td>84664</td>
#     </tr>
#     <tr>
#       <th>retro_sample_groups</th>
#       <td>100</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Recombinants data file with unshifted breakpoint intervals.
# https://github.com/jeromekelleher/sc2ts-paper/commit/c7e26e629a955ef093cd5d9aed6d7c47daf2ee2a
old_file = "../data/recombinants.csv"
old_df = pd.read_csv(old_file)
old_df.head(1)
# Out:
#    Unnamed: 0  recombinant  descendants   sample   sample_id sample_pango  \
# 0         766      1280342            1  1280341  ERR9939974       BA.4.1
#
#    interval_left  interval_right  num_mutations  date_added  \
# 0            695             958              1  2022-06-27
#
#                            group_id  parent_left parent_left_pango  \
# 0  96ff31d5f4931e21077b36d955f3d19b      1253363          BA.5.2.1
#
#    parent_right parent_right_pango  mrca       t_mrca  diffs  max_run_length
# 0       1232376             BA.4.1    59  1114.000001     25               1

# %%
data = []
for u in ti.recombinants:
    interval_right_shifted = int(max(ts.edges_left[ts.edges_child == u]))
    data.append(
        {
            "recombinant": u,
            "interval_right_shifted": interval_right_shifted,
        }
    )
new_df = pd.DataFrame(data)
new_df.head(1)
# Out:
#    recombinant  interval_right_shifted
# 0         1530                   13617

# %%
merged_df = new_df.merge(old_df, on="recombinant")
merged_df.head(1)
# Out:
#    recombinant  interval_right_shifted  Unnamed: 0  descendants  sample  \
# 0         1530                   13617           0            1    1529
#
#     sample_id sample_pango  interval_left  interval_right  num_mutations  \
# 0  ERR4437465      B.1.157           8783           13617              2
#
#    date_added                          group_id  parent_left  \
# 0  2020-03-22  052b938d3189a1c873abd3ffd894e4c6         1121
#
#   parent_left_pango  parent_right parent_right_pango  mrca  t_mrca  diffs  \
# 0               A.5           832            B.1.157     1  1153.0     13
#
#    max_run_length
# 0               0

# %%
num_diffs = np.sum(merged_df["interval_right_shifted"] != merged_df["interval_right"])
print(f"Total: {len(merged_df)}")
print(f"Diff: {num_diffs}")
# Out:
# Total: 929
# Diff: 102

# %%
data = []
for i, row in merged_df.iterrows():
    recombinant = row["recombinant"]
    parent_left = row["parent_left"]
    parent_right = row["parent_right"]
    if row["interval_right_shifted"] != row["interval_right"]:
        interval_right = row["interval_right_shifted"]
        interval_left = sc2ts.utils.compute_left_bound(
            ts,
            parents=[parent_left, parent_right],
            right=interval_right,
        )
    else:
        interval_left = row["interval_left"]
        interval_right = row["interval_right"]
    data.append(
        {
            "recombinant": recombinant,
            "descendants": row["descendants"],
            "sample": row["sample"],
            "sample_id": row["sample_id"],
            "sample_pango": row["sample_pango"],
            "interval_left": interval_left,
            "interval_right": interval_right,
            "num_mutations": row["num_mutations"],
            "date_added": row["date_added"],
            "group_id": row["group_id"],
            "parent_left": parent_left,
            "parent_left_pango": row["parent_left_pango"],
            "parent_right": parent_right,
            "parent_right_pango": row["parent_right_pango"],
            "mrca": row["mrca"],
            "t_mrca": row["t_mrca"],
            "diffs": row["diffs"],
            "max_run_length": row["max_run_length"],
        }
    )
updated_df = pd.DataFrame(data)
updated_df.head(1)
# Out:
#    recombinant  descendants  sample   sample_id sample_pango  interval_left  \
# 0         1530            1    1529  ERR4437465      B.1.157           8783
#
#    interval_right  num_mutations  date_added  \
# 0           13617              2  2020-03-22
#
#                            group_id  parent_left parent_left_pango  \
# 0  052b938d3189a1c873abd3ffd894e4c6         1121               A.5
#
#    parent_right parent_right_pango  mrca  t_mrca  diffs  max_run_length
# 0           832            B.1.157     1  1153.0     13               0

# %%
updated_df.to_csv(
    "../data/recombinants_bpshift.csv",
    index=False,
)
