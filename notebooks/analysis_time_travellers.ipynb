# %% [markdown]
# # Time travellers in Viridian
#
# In this notebook we do some brief analysis on the time travelling samples (those with a collection date that is much earlier than their true collection date) in the Viridian dataset.
#
# This also provides a useful example of how to extract and manipulate metadata fields from the VCF Zarr encoding using Pandas.

# %%
import sc2ts

# %%
ds = sc2ts.Dataset("../data/viridian_mafft_2024-10-14_v1.vcz.zip")
ds
# Out:
# Dataset at ../data/viridian_mafft_2024-10-14_v1.vcz.zip with 4484157 samples, 29903 variants, and 30 metadata fields. See ds.metadata.field_descriptors() for a description of the fields.

# %%
ds.metadata.field_descriptors()
# Out:
#                            dtype  \
# field
# Artic_primer_version      object
# Collection_date           object
# Country                   object
# Date_tree                 object
# Date_tree_order           object
# Experiment                object
# First_created             object
# Genbank_N                  int16
# Genbank_accession         object
# Genbank_other_runs        object
# Genbank_pangolin          object
# Genbank_scorpio           object
# Genbank_tree_name         object
# In_Viridian_tree            bool
# In_intersection             bool
# In_may_2024_preprint        bool
# Platform                  object
# Region                    object
# Run_count                   int8
# Sample                    object
# Study                     object
# Viridian_N                 int16
# Viridian_amplicon_scheme  object
# Viridian_cons_het           int8
# Viridian_cons_len          int16
# Viridian_pangolin         object
# Viridian_pangolin_1.29    object
# Viridian_result           object
# Viridian_scorpio          object
# Viridian_scorpio_1.29     object
#
#                                                                 description
# field
# Artic_primer_version      If known, the ARTIC primer scheme from ENA met...
# Collection_date                           collection_date from ENA metadata
# Country                   Country from ENA metadata. If ':' was in the e...
# Date_tree                 A consensus date, using up 3 sources of data f...
# Date_tree_order           This helped define the order in which the samp...
# Experiment                           experiment_accession from ENA metadata
# First_created                           first_created from the ENA metadata
# Genbank_N                 Number of Ns in the GenBank consensus sequence...
# Genbank_accession             This is the GenBank accession of the assembly
# Genbank_other_runs        Any other run accessions associated with the G...
# Genbank_pangolin          Pangolin call from the GenBank consensus seque...
# Genbank_scorpio           Scorpio call from the GenBank consensus sequen...
# Genbank_tree_name                    Name of the sample in the GenBank tree
# In_Viridian_tree          'T' or 'F' to indicate if the sample is in the...
# In_intersection           'T' or 'F' to indicate if the sample is in the...
# In_may_2024_preprint      Whether or not this run was in the May 2024 pr...
# Platform                              instrument_platform from ENA metadata
# Region                    Region from ENA metadata, if present. If ':' w...
# Run_count                      The number of runs from the sample accession
# Sample                                   sample_accession from ENA metadata
# Study                                     study_accession from ENA metadata
# Viridian_N                Number of Ns in the viridian consensus sequenc...
# Viridian_amplicon_scheme                 Amplicon scheme called by Viridian
# Viridian_cons_het
# Viridian_cons_len         Length of the Viridian consensus sequence Viri...
# Viridian_pangolin         Pangolin call from the Viridian consensus sequ...
# Viridian_pangolin_1.29    Pangolin call from the Viridian consensus sequ...
# Viridian_result           This is 'PASS' if Viridian finished and made a...
# Viridian_scorpio          Scorpio call from the Viridian consensus seque...
# Viridian_scorpio_1.29     Scorpio call from the Viridian consensus seque...

# %%
df = ds.metadata.as_dataframe(["Date_tree", "Viridian_scorpio_1.29"])
df
# Out:
#               Date_tree Viridian_scorpio_1.29
# sample_id
# SRR11772659  2020-01-19                     .
# SRR11597132  2020-01-29                     .
# SRR12162233  2020-01-30                     .
# SRR12162234  2020-01-30                     .
# SRR11597217  2020-02-02                     .
# ...                 ...                   ...
# ERR13177478  2023-04-20    Omicron (XBB-like)
# ERR13177479  2023-04-21    Omicron (XBB-like)
# ERR13177480  2023-04-24    Omicron (XBB-like)
# ERR13177481  2023-04-26    Omicron (XBB-like)
# ERR13177482  2023-04-27    Omicron (XBB-like)
#
# [4484157 rows x 2 columns]

# %% [markdown]
# Filter out incomplete dates for simplicity. Full ISO dates are 10 chars long.

# %%
df = df[df["Date_tree"].str.len() == 10]
df
# Out:
#               Date_tree Viridian_scorpio_1.29
# sample_id
# SRR11772659  2020-01-19                     .
# SRR11597132  2020-01-29                     .
# SRR12162233  2020-01-30                     .
# SRR12162234  2020-01-30                     .
# SRR11597217  2020-02-02                     .
# ...                 ...                   ...
# ERR13177478  2023-04-20    Omicron (XBB-like)
# ERR13177479  2023-04-21    Omicron (XBB-like)
# ERR13177480  2023-04-24    Omicron (XBB-like)
# ERR13177481  2023-04-26    Omicron (XBB-like)
# ERR13177482  2023-04-27    Omicron (XBB-like)
#
# [4458826 rows x 2 columns]

# %%
dfg = df.groupby("Viridian_scorpio_1.29").min()
dfg
# Out:
#                                    Date_tree
# Viridian_scorpio_1.29
# .                                 2020-01-01
# A.23.1-like                       2020-04-12
# A.23.1-like+E484K                 2020-12-26
# AV.1-like                         2020-12-31
# Alpha (B.1.1.7-like)              2020-01-12
# B.1.1.318-like                    2020-12-31
# B.1.1.7-like+E484K                2020-12-08
# B.1.617.1-like                    2020-03-17
# B.1.617.3-like                    2020-12-31
# Beta (B.1.351-like)               2020-05-27
# Delta (AY.4-like)                 2020-10-27
# Delta (AY.4.2-like)               2020-12-21
# Delta (B.1.617.2-like)            2020-05-08
# Delta (B.1.617.2-like) +K417N     2020-12-31
# Epsilon (B.1.427-like)            2020-09-17
# Epsilon (B.1.429-like)            2020-09-25
# Eta (B.1.525-like)                2020-12-15
# Gamma (P.1-like)                  2020-05-06
# Iota (B.1.526-like)               2020-12-31
# Lambda (C.37-like)                2021-01-29
# Mu (B.1.621-like)                 2020-12-31
# Omicron (BA.1-like)               2020-09-22
# Omicron (BA.2-like)               2020-01-10
# Omicron (BA.3-like)               2020-12-31
# Omicron (BA.4-like)               2020-07-02
# Omicron (BA.5-like)               2020-03-31
# Omicron (Unassigned)              2020-06-30
# Omicron (XBB-like)                2020-10-23
# Omicron (XBB.1-like)              2020-12-22
# Omicron (XBB.1.16-like)           2020-11-20
# Omicron (XBB.1.5-like)            2022-01-17
# Omicron (XE-like)                 2022-01-19
# Probable Omicron (BA.1-like)      2020-12-31
# Probable Omicron (BA.2-like)      2021-12-30
# Probable Omicron (BA.3-like)      2022-01-28
# Probable Omicron (BA.5-like)      2022-06-11
# Probable Omicron (Unassigned)     2020-12-31
# Probable Omicron (XBB-like)       2022-10-04
# Probable Omicron (XBB.1-like)     2022-12-12
# Probable Omicron (XBB.1.16-like)  2023-07-03
# Probable Omicron (XBB.1.5-like)   2023-01-07
# Theta (P.3-like)                  2021-02-01
# Zeta (P.2-like)                   2020-05-04

# %% [markdown]
# As a very rough proxy for the existance of time travellers, we just look at the minimum date observed within each of the Scorpio designations. Nearly all of these are post 2020, but yet most have samples in 2020.

# %%
dfg_2020 = dfg[dfg["Date_tree"] < "2021"]

# %%
dfg_2020.shape
# Out:
# (32, 1)

# %%
dfg.shape
# Out:
# (43, 1)

# %%
dfg_2020
# Out:
#                                 Date_tree
# Viridian_scorpio_1.29
# .                              2020-01-01
# A.23.1-like                    2020-04-12
# A.23.1-like+E484K              2020-12-26
# AV.1-like                      2020-12-31
# Alpha (B.1.1.7-like)           2020-01-12
# B.1.1.318-like                 2020-12-31
# B.1.1.7-like+E484K             2020-12-08
# B.1.617.1-like                 2020-03-17
# B.1.617.3-like                 2020-12-31
# Beta (B.1.351-like)            2020-05-27
# Delta (AY.4-like)              2020-10-27
# Delta (AY.4.2-like)            2020-12-21
# Delta (B.1.617.2-like)         2020-05-08
# Delta (B.1.617.2-like) +K417N  2020-12-31
# Epsilon (B.1.427-like)         2020-09-17
# Epsilon (B.1.429-like)         2020-09-25
# Eta (B.1.525-like)             2020-12-15
# Gamma (P.1-like)               2020-05-06
# Iota (B.1.526-like)            2020-12-31
# Mu (B.1.621-like)              2020-12-31
# Omicron (BA.1-like)            2020-09-22
# Omicron (BA.2-like)            2020-01-10
# Omicron (BA.3-like)            2020-12-31
# Omicron (BA.4-like)            2020-07-02
# Omicron (BA.5-like)            2020-03-31
# Omicron (Unassigned)           2020-06-30
# Omicron (XBB-like)             2020-10-23
# Omicron (XBB.1-like)           2020-12-22
# Omicron (XBB.1.16-like)        2020-11-20
# Probable Omicron (BA.1-like)   2020-12-31
# Probable Omicron (Unassigned)  2020-12-31
# Zeta (P.2-like)                2020-05-04
