# %% [markdown]
# # Get a set of fixed-date samples to see VOCs
#
# Getting saltational variants started off in the presence of time travellers is a significant challenge. One way we can get some sequences of which we are confident are important to these outbreaks and have reasonably accurate dates is to look at the Pango designation data.
#
# We then merge data and figure out which of these are in the Viridian dataset by looking at the ENA data.
#
# See https://github.com/jeromekelleher/sc2ts-paper/issues/268

# %% [markdown]
# #### Download files

# %%
# %%bash
# wget --quiet https://raw.githubusercontent.com/cov-lineages/pango-designation/16205e716c6a68ff1c3d0f26f0c77478682368ac/lineages.csv

# %%
# %%bash
# curl -s -X 'GET' \
#   'https://www.ebi.ac.uk/ena/portal/api/filereport?result=read_run&accession=PRJEB37886&fields=sample_accession%2Csample_alias&limit=0&format=tsv&download=true' \
#   -H 'accept: */*' > filereport_read_run_PRJEB37886_tsv.txt

# %%
# %%bash
# wget --quiet --content-disposition https://figshare.com/ndownloader/files/49694808

# %% [markdown]
# #### Parse files

# %%
import pandas as pd

# lineage, sample name
pango = pd.read_csv("lineages.csv", sep=",")
pango["sample_name"] = [s.split("/")[1] for s in pango["taxon"]]
pango
# Out:
#                                  taxon   lineage       sample_name
# 0         Belgium/UZA-UA-48355442/2023       XBZ   UZA-UA-48355442
# 1                Norway/Ahus-4881/2023       XBZ         Ahus-4881
# 2            England/PHEP-YYG8X8X/2023       XBZ      PHEP-YYG8X8X
# 3        Germany/RP-RKI-I-1082931/2022       XBZ  RP-RKI-I-1082931
# 4        Germany/BY-RKI-I-1083943/2022       XBZ  BY-RKI-I-1083943
# ...                                ...       ...               ...
# 2587341   SouthAfrica/NICD-N58702/2024  LB.1.3.4       NICD-N58702
# 2587342   SouthAfrica/NICD-N58691/2024  LB.1.3.4       NICD-N58691
# 2587343   SouthAfrica/NICD-N58721/2024  LB.1.3.4       NICD-N58721
# 2587344   SouthAfrica/NICD-N58715/2024  LB.1.3.4       NICD-N58715
# 2587345    Canada/BC-BCCDC-732955/2024  LB.1.3.4   BC-BCCDC-732955
#
# [2587346 rows x 3 columns]

# %%
pango = pango.set_index("sample_name")

# %%
# run accession, sample name
ena = pd.read_csv("filereport_read_run_PRJEB37886_tsv.txt", sep="\t")
ena["sample_name"] = [s.split("/")[1] for s in ena["sample_alias"]]
ena
# Out:
#         run_accession         sample_alias sample_accession   sample_name
# 0         ERR10120258  COG-UK/QEUH-3F6D670   SAMEA110754665  QEUH-3F6D670
# 1         ERR10120260  COG-UK/QEUH-3F6D69E   SAMEA110754667  QEUH-3F6D69E
# 2         ERR10120263  COG-UK/QEUH-3F6D6DA   SAMEA110754670  QEUH-3F6D6DA
# 3         ERR10120264  COG-UK/LSPA-3F69DBB   SAMEA110754671  LSPA-3F69DBB
# 4         ERR10120276  COG-UK/QEUH-3F6D731   SAMEA110754683  QEUH-3F6D731
# ...               ...                  ...              ...           ...
# 2700696    ERR9654574  COG-UK/QEUH-3D8C798    SAMEA14260946  QEUH-3D8C798
# 2700697    ERR9654575  COG-UK/QEUH-3D8AC8C    SAMEA14260947  QEUH-3D8AC8C
# 2700698    ERR9654587  COG-UK/QEUH-3D8C7A7    SAMEA14260959  QEUH-3D8C7A7
# 2700699    ERR9654607  COG-UK/QEUH-3D8D65E    SAMEA14260979  QEUH-3D8D65E
# 2700700    ERR9654615  COG-UK/QEUH-3D8B0F8    SAMEA14260987  QEUH-3D8B0F8
#
# [2700701 rows x 4 columns]

# %%
ena = ena.set_index("sample_name")

# %%
pango_ena = pango.join(ena, how="inner")
pango_ena
# Out:
#                                     taxon  lineage run_accession  \
# sample_name
# LSPA-325F505B  England/LSPA-325F505B/2022      XBZ   ERR10513123
# QEUH-326B5575  England/QEUH-326B5575/2023      XBZ   ERR10863933
# QEUH-326B81BA  England/QEUH-326B81BA/2023      XBZ   ERR10887233
# ALDP-94A6E1      England/ALDP-94A6E1/2020        A    ERR4639199
# ALDP-94A6C3      England/ALDP-94A6C3/2020        A    ERR4639208
# ...                                   ...      ...           ...
# WSI-3316A5BD    England/WSI-3316A5BD/2023  JN.1.64   ERR12383654
# WSI-3319FCF6    England/WSI-3319FCF6/2024  JN.1.64   ERR12658112
# WSI-331EF116    England/WSI-331EF116/2024  JN.1.65   ERR12742963
# WSI-331C96F5    England/WSI-331C96F5/2024  JN.1.65   ERR12658286
# WSI-331857E3    England/WSI-331857E3/2023  JN.1.65   ERR12405379
#
#                        sample_alias sample_accession
# sample_name
# LSPA-325F505B  COG-UK/LSPA-325F505B   SAMEA112160435
# QEUH-326B5575  COG-UK/QEUH-326B5575   SAMEA112622902
# QEUH-326B81BA  COG-UK/QEUH-326B81BA   SAMEA112641438
# ALDP-94A6E1      COG-UK/ALDP-94A6E1     SAMEA7359442
# ALDP-94A6C3      COG-UK/ALDP-94A6C3     SAMEA7359451
# ...                             ...              ...
# WSI-3316A5BD    COG-UK/WSI-3316A5BD   SAMEA115054198
# WSI-3319FCF6    COG-UK/WSI-3319FCF6   SAMEA115291849
# WSI-331EF116    COG-UK/WSI-331EF116   SAMEA115406129
# WSI-331C96F5    COG-UK/WSI-331C96F5   SAMEA115292022
# WSI-331857E3    COG-UK/WSI-331857E3   SAMEA115079671
#
# [463787 rows x 5 columns]

# %%
del pango, ena

# %%
# Run (strain)
viridian = pd.read_csv("run_metadata.v05.tsv.gz", sep="\t").set_index("Run")
viridian
# Out:
# /tmp/ipykernel_58894/3081282411.py:2: DtypeWarning: Columns (18,20,21,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   viridian = pd.read_csv("run_metadata.v05.tsv.gz", sep="\t").set_index("Run")
#             In_may_2024_preprint       Study          Sample   Experiment  \
# Run
# ERR6546375                     T  PRJEB47121    SAMEA9781395   ERX6172603
# ERR6546376                     T  PRJEB47121    SAMEA9781396   ERX6172604
# ERR6546377                     T  PRJEB47121    SAMEA9781397   ERX6172605
# ERR6546378                     T  PRJEB47121    SAMEA9781398   ERX6172606
# ERR6546379                     T  PRJEB47121    SAMEA9781399   ERX6172607
# ...                          ...         ...             ...          ...
# ERR13177478                    F  PRJEB46220  SAMEA114210144  ERX12548855
# ERR13177479                    F  PRJEB46220  SAMEA114210145  ERX12548856
# ERR13177480                    F  PRJEB46220  SAMEA114210146  ERX12548857
# ERR13177481                    F  PRJEB46220  SAMEA114210147  ERX12548858
# ERR13177482                    F  PRJEB46220  SAMEA114210148  ERX12548859
#
#              Run_count  Platform    Country Region Collection_date  \
# Run
# ERR6546375           1  ILLUMINA    Estonia   none      2021-08-02
# ERR6546376           1  ILLUMINA    Estonia   none      2021-08-02
# ERR6546377           1  ILLUMINA    Estonia   none      2021-08-02
# ERR6546378           1  ILLUMINA    Estonia   none      2021-08-02
# ERR6546379           1  ILLUMINA    Estonia   none      2021-08-02
# ...                ...       ...        ...    ...             ...
# ERR13177478          1  ILLUMINA  Argentina   none      2023-04-20
# ERR13177479          1  ILLUMINA  Argentina   none      2023-04-21
# ERR13177480          1  ILLUMINA  Argentina   none      2023-04-24
# ERR13177481          1  ILLUMINA  Argentina   none      2023-04-26
# ERR13177482          1  ILLUMINA  Argentina   none      2023-04-27
#
#             First_created  ... Genbank_N Viridian_pangolin  \
# Run                        ...
# ERR6546375     2021-08-22  ...         .            AY.100
# ERR6546376     2021-08-22  ...         .            AY.122
# ERR6546377     2021-08-22  ...         .         B.1.617.2
# ERR6546378     2021-08-22  ...         .         B.1.617.2
# ERR6546379     2021-08-22  ...         .         B.1.617.2
# ...                   ...  ...       ...               ...
# ERR13177478    2024-05-30  ...         .                 .
# ERR13177479    2024-05-30  ...         .                 .
# ERR13177480    2024-05-30  ...         .                 .
# ERR13177481    2024-05-30  ...         .                 .
# ERR13177482    2024-05-30  ...         .                 .
#
#                    Viridian_scorpio Genbank_pangolin Genbank_scorpio  \
# Run
# ERR6546375   Delta (B.1.617.2-like)                .               .
# ERR6546376   Delta (B.1.617.2-like)                .               .
# ERR6546377   Delta (B.1.617.2-like)                .               .
# ERR6546378   Delta (B.1.617.2-like)                .               .
# ERR6546379   Delta (B.1.617.2-like)                .               .
# ...                             ...              ...             ...
# ERR13177478                       .                .               .
# ERR13177479                       .                .               .
# ERR13177480                       .                .               .
# ERR13177481                       .                .               .
# ERR13177482                       .                .               .
#
#             Genbank_tree_name Viridian_cons_len Viridian_cons_het  \
# Run
# ERR6546375                  .             29810                 0
# ERR6546376                  .             29807                 3
# ERR6546377                  .             29808                16
# ERR6546378                  .             29808                13
# ERR6546379                  .             29800                18
# ...                       ...               ...               ...
# ERR13177478                 .             29757                 3
# ERR13177479                 .             29759                 0
# ERR13177480                 .             29756                 2
# ERR13177481                 .             29759                 1
# ERR13177482                 .             29756                 1
#
#             Viridian_pangolin_1.29   Viridian_scorpio_1.29
# Run
# ERR6546375                  AY.100  Delta (B.1.617.2-like)
# ERR6546376                  AY.122  Delta (B.1.617.2-like)
# ERR6546377               B.1.617.2  Delta (B.1.617.2-like)
# ERR6546378               B.1.617.2  Delta (B.1.617.2-like)
# ERR6546379               B.1.617.2  Delta (B.1.617.2-like)
# ...                            ...                     ...
# ERR13177478                XBB.1.5      Omicron (XBB-like)
# ERR13177479            XBB.1.5.107      Omicron (XBB-like)
# ERR13177480                XBB.1.5      Omicron (XBB-like)
# ERR13177481            XBB.1.5.107      Omicron (XBB-like)
# ERR13177482            XBB.1.5.107      Omicron (XBB-like)
#
# [5959032 rows x 30 columns]

# %%
pango_ena = pango_ena.set_index("run_accession")
pango_ena
# Out:
#                                     taxon  lineage          sample_alias  \
# run_accession
# ERR10513123    England/LSPA-325F505B/2022      XBZ  COG-UK/LSPA-325F505B
# ERR10863933    England/QEUH-326B5575/2023      XBZ  COG-UK/QEUH-326B5575
# ERR10887233    England/QEUH-326B81BA/2023      XBZ  COG-UK/QEUH-326B81BA
# ERR4639199       England/ALDP-94A6E1/2020        A    COG-UK/ALDP-94A6E1
# ERR4639208       England/ALDP-94A6C3/2020        A    COG-UK/ALDP-94A6C3
# ...                                   ...      ...                   ...
# ERR12383654     England/WSI-3316A5BD/2023  JN.1.64   COG-UK/WSI-3316A5BD
# ERR12658112     England/WSI-3319FCF6/2024  JN.1.64   COG-UK/WSI-3319FCF6
# ERR12742963     England/WSI-331EF116/2024  JN.1.65   COG-UK/WSI-331EF116
# ERR12658286     England/WSI-331C96F5/2024  JN.1.65   COG-UK/WSI-331C96F5
# ERR12405379     England/WSI-331857E3/2023  JN.1.65   COG-UK/WSI-331857E3
#
#               sample_accession
# run_accession
# ERR10513123     SAMEA112160435
# ERR10863933     SAMEA112622902
# ERR10887233     SAMEA112641438
# ERR4639199        SAMEA7359442
# ERR4639208        SAMEA7359451
# ...                        ...
# ERR12383654     SAMEA115054198
# ERR12658112     SAMEA115291849
# ERR12742963     SAMEA115406129
# ERR12658286     SAMEA115292022
# ERR12405379     SAMEA115079671
#
# [463787 rows x 4 columns]

# %%
joined = viridian.join(pango_ena, how="inner")
del viridian, pango_ena

# %%
joined
# Out:
#             In_may_2024_preprint       Study          Sample   Experiment  \
# Run
# ERR10000002                    T  PRJEB37886  SAMEA110427045   ERX9541018
# ERR10000004                    T  PRJEB37886  SAMEA110427047   ERX9541020
# ERR10000005                    T  PRJEB37886  SAMEA110427048   ERX9541021
# ERR10000006                    T  PRJEB37886  SAMEA110427049   ERX9541022
# ERR10000017                    T  PRJEB37886  SAMEA110427060   ERX9541033
# ...                          ...         ...             ...          ...
# ERR12658247                    F  PRJEB37886  SAMEA115291983  ERX12032539
# ERR12658261                    F  PRJEB37886  SAMEA115291997  ERX12032553
# ERR12658286                    F  PRJEB37886  SAMEA115292022  ERX12032578
# ERR12658298                    F  PRJEB37886  SAMEA115292034  ERX12032590
# ERR12658300                    F  PRJEB37886  SAMEA115292036  ERX12032592
#
#              Run_count  Platform         Country Region Collection_date  \
# Run
# ERR10000002          1  ILLUMINA  United Kingdom   none      2022-07-05
# ERR10000004          1  ILLUMINA  United Kingdom   none      2022-07-04
# ERR10000005          1  ILLUMINA  United Kingdom   none      2022-07-05
# ERR10000006          1  ILLUMINA  United Kingdom   none      2022-07-02
# ERR10000017          1  ILLUMINA  United Kingdom   none      2022-07-04
# ...                ...       ...             ...    ...             ...
# ERR12658247          1  ILLUMINA  United Kingdom   none      2024-01-30
# ERR12658261          1  ILLUMINA  United Kingdom   none      2024-01-28
# ERR12658286          1  ILLUMINA  United Kingdom   none      2024-01-29
# ERR12658298          1  ILLUMINA  United Kingdom   none      2024-01-24
# ERR12658300          1  ILLUMINA  United Kingdom   none      2024-01-30
#
#             First_created  ...      Genbank_scorpio  \
# Run                        ...
# ERR10000002    2022-07-28  ...  Omicron (BA.5-like)
# ERR10000004    2022-07-28  ...  Omicron (BA.5-like)
# ERR10000005    2022-07-28  ...  Omicron (BA.5-like)
# ERR10000006    2022-07-28  ...  Omicron (BA.5-like)
# ERR10000017    2022-07-28  ...  Omicron (BA.5-like)
# ...                   ...  ...                  ...
# ERR12658247    2024-02-13  ...                    .
# ERR12658261    2024-02-13  ...                    .
# ERR12658286    2024-02-13  ...                    .
# ERR12658298    2024-02-13  ...                    .
# ERR12658300    2024-02-13  ...                    .
#
#                           Genbank_tree_name Viridian_cons_len  \
# Run
# ERR10000002  ERR10000002.genbank.OX252821.1             29770
# ERR10000004  ERR10000004.genbank.OX254093.1             29728
# ERR10000005  ERR10000005.genbank.OX253820.1             29770
# ERR10000006  ERR10000006.genbank.OX253426.1             29770
# ERR10000017  ERR10000017.genbank.OX254399.1             29471
# ...                                     ...               ...
# ERR12658247                               .             29773
# ERR12658261                               .             29474
# ERR12658286                               .             29773
# ERR12658298                               .             29773
# ERR12658300                               .             29773
#
#             Viridian_cons_het Viridian_pangolin_1.29 Viridian_scorpio_1.29  \
# Run
# ERR10000002                 2                  BF.26   Omicron (BA.5-like)
# ERR10000004                 2                 BA.5.2   Omicron (BA.5-like)
# ERR10000005                 4                   BF.4   Omicron (BA.5-like)
# ERR10000006                 2              BA.5.2.21   Omicron (BA.5-like)
# ERR10000017                 3              BA.5.1.22   Omicron (BA.5-like)
# ...                       ...                    ...                   ...
# ERR12658247                 0                JN.1.39   Omicron (BA.2-like)
# ERR12658261                 0              JN.1.39.3   Omicron (BA.2-like)
# ERR12658286                 1                JN.1.65   Omicron (BA.2-like)
# ERR12658298                 2                JN.1.49   Omicron (BA.2-like)
# ERR12658300                 2                JN.1.52   Omicron (BA.2-like)
#
#                                   taxon    lineage         sample_alias  \
# Run
# ERR10000002  Scotland/LSPA-3EBE8D5/2022      BF.26  COG-UK/LSPA-3EBE8D5
# ERR10000004  Scotland/LSPA-3EBBC63/2022     BA.5.2  COG-UK/LSPA-3EBBC63
# ERR10000005  Scotland/LSPA-3EBE8E4/2022       BF.4  COG-UK/LSPA-3EBE8E4
# ERR10000006  Scotland/LSPA-3EBBDD9/2022     BA.5.2  COG-UK/LSPA-3EBBDD9
# ERR10000017  Scotland/LSPA-3EBC0DF/2022  BA.5.1.22  COG-UK/LSPA-3EBC0DF
# ...                                 ...        ...                  ...
# ERR12658247   England/WSI-331C9C6C/2024    JN.1.39  COG-UK/WSI-331C9C6C
# ERR12658261   England/WSI-331C9AF9/2024  JN.1.39.3  COG-UK/WSI-331C9AF9
# ERR12658286   England/WSI-331C96F5/2024    JN.1.65  COG-UK/WSI-331C96F5
# ERR12658298   England/WSI-331C9E84/2024    JN.1.49  COG-UK/WSI-331C9E84
# ERR12658300   England/WSI-331C9DA5/2024    JN.1.52  COG-UK/WSI-331C9DA5
#
#             sample_accession
# Run
# ERR10000002   SAMEA110427045
# ERR10000004   SAMEA110427047
# ERR10000005   SAMEA110427048
# ERR10000006   SAMEA110427049
# ERR10000017   SAMEA110427060
# ...                      ...
# ERR12658247   SAMEA115291983
# ERR12658261   SAMEA115291997
# ERR12658286   SAMEA115292022
# ERR12658298   SAMEA115292034
# ERR12658300   SAMEA115292036
#
# [455593 rows x 34 columns]

# %% [markdown]
# These should all be COGUK samples now. Check on country, as a sanity check

# %%
joined.Country.unique()
# Out:
# array(['United Kingdom', 'UNKNOWN'], dtype=object)

# %%
# Subset down to the columns that we're using here and chuck out 2020-12-31 and non full precision dates
joined = joined[["Date_tree", "lineage", "Viridian_pangolin_1.29"]]
joined = joined[(joined["Date_tree"] != "2020-12-31") & (joined["Date_tree"].str.len() == 10)]

# %% [markdown]
# #### Search for seed samples
#
# Use this joined dataframe now to extract some early sequences for each lineage of interest.

# %%
def extract_lineage(lineage, max_rows=10):
    df = joined[joined.lineage == lineage].sort_values("Date_tree")
    print("Got", df.shape[0], " runs")
    return df.head(max_rows)

extract_lineage("B.1.617")
# Out:
# Got 0  runs
# Empty DataFrame
# Columns: [Date_tree, lineage, Viridian_pangolin_1.29]
# Index: []

# %%
extract_lineage("B.1.617.1")
# Out:
# Got 103  runs
#              Date_tree    lineage Viridian_pangolin_1.29
# Run
# ERR5461550  2021-02-22  B.1.617.1              B.1.617.1
# ERR5461562  2021-02-22  B.1.617.1                B.1.617
# ERR5469699  2021-03-02  B.1.617.1              B.1.617.1
# ERR5469807  2021-03-04  B.1.617.1              B.1.617.1
# ERR5486121  2021-03-04  B.1.617.1              B.1.617.1
# ERR5539924  2021-03-04  B.1.617.1                B.1.617
# ERR5521603  2021-03-06  B.1.617.1                B.1.617
# ERR5531143  2021-03-07  B.1.617.1              B.1.617.1
# ERR5532096  2021-03-07  B.1.617.1              B.1.617.1
# ERR5532118  2021-03-07  B.1.617.1              B.1.617.1

# %%
extract_lineage("B.1.617.2")
# Out:
# Got 3030  runs
#              Date_tree    lineage Viridian_pangolin_1.29
# Run
# ERR5653377  2021-03-18  B.1.617.2              B.1.617.2
# ERR5656218  2021-03-18  B.1.617.2              B.1.617.2
# ERR5676810  2021-03-23  B.1.617.2              B.1.617.2
# ERR5690893  2021-03-28  B.1.617.2              B.1.617.2
# ERR5690055  2021-03-30  B.1.617.2              B.1.617.2
# ERR5690921  2021-03-30  B.1.617.2              B.1.617.2
# ERR5701881  2021-03-30  B.1.617.2              B.1.617.2
# ERR5695631  2021-03-30  B.1.617.2              B.1.617.2
# ERR5690052  2021-03-31  B.1.617.2              B.1.617.2
# ERR5690920  2021-03-31  B.1.617.2              B.1.617.2

# %%
extract_lineage("BA.1")
# Out:
# Got 17873  runs
#              Date_tree lineage Viridian_pangolin_1.29
# Run
# ERR7443564  2021-11-22    BA.1                   BA.1
# ERR7552222  2021-11-23    BA.1                   BA.1
# ERR7600669  2021-11-25    BA.1                   BA.1
# ERR7612412  2021-11-25    BA.1                   BA.1
# ERR7601682  2021-11-26    BA.1                   BA.1
# ERR7601847  2021-11-26    BA.1                   BA.1
# ERR7611335  2021-11-27    BA.1                   BA.1
# ERR7615361  2021-11-27    BA.1                   BA.1
# ERR7713581  2021-11-27    BA.1                   BA.1
# ERR7650807  2021-11-27    BA.1                   BA.1

# %%
extract_lineage("BA.2")
# Out:
# Got 34310  runs
#              Date_tree lineage Viridian_pangolin_1.29
# Run
# ERR7965207  2022-01-03    BA.2                   BA.2
# ERR7966705  2022-01-03    BA.2                   BA.2
# ERR7970740  2022-01-04    BA.2                   BA.2
# ERR7972740  2022-01-04    BA.2                   BA.2
# ERR8000637  2022-01-04    BA.2                   BA.2
# ERR8004998  2022-01-05    BA.2                BA.2.10
# ERR8031838  2022-01-07    BA.2                   BA.2
# ERR8035855  2022-01-08    BA.2                   BA.2
# ERR8035243  2022-01-08    BA.2                   BA.2
# ERR8068119  2022-01-08    BA.2                   BA.2

# %%
extract_lineage("BA.4")
# Out:
# Got 780  runs
#              Date_tree lineage Viridian_pangolin_1.29
# Run
# ERR9460737  2022-03-22    BA.4                   BA.4
# ERR9478457  2022-03-22    BA.4                   BA.4
# ERR9618865  2022-04-07    BA.4                   BA.4
# ERR9824759  2022-04-10    BA.4                   BA.4
# ERR9624616  2022-04-11    BA.4                   BA.4
# ERR9623118  2022-04-11    BA.4                   BA.4
# ERR9701287  2022-04-12    BA.4                   BA.4
# ERR9645527  2022-04-14    BA.4                   BA.4
# ERR9840429  2022-04-16    BA.4                   BA.4
# ERR9654878  2022-04-19    BA.4                   BA.4
