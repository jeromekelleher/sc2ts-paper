# %% [markdown]
# ## Accuracy of pango sample assigments in sc2ts ARG
#
# In this notebook we examine how well the pango assignments computed in the sc2ts ARG agree with those from the source Viridian consensus sequences.

# %%
import sc2ts
import tszip
import pathlib
import numpy as np

datadir = pathlib.Path("../data")

# %%
ds = sc2ts.Dataset(datadir / "viridian_mafft_2024-10-14_v1.vcz.zip")
ds

# %%
ts = tszip.load(datadir / "sc2ts_v1_2023-02-21_pp_dated_remapped_bps_pango_mmps.trees.tsz")

# %% [markdown]
# Get the per-node data computed by sc2ts and join with the source Viridian data from dataset

# %%
df = sc2ts.node_data(ts)
df = df[df.is_sample].set_index("sample_id")
df
# Out:
#                   pango                 scorpio  node_id  is_sample  \
# sample_id
# SRR11772659           A                       .        2       True
# SRR11397727           B                       .        3       True
# SRR11397730           B                       .        4       True
# SRR11597198           A                       .        6       True
# SRR11597221           A                       .        7       True
# ...                 ...                     ...      ...        ...
# ERR10937847     XBB.1.5  Omicron (XBB.1.5-like)  2688999       True
# ERR10937891  XBB.1.5.62  Omicron (XBB.1.5-like)  2689000       True
# ERR10937893        FD.1  Omicron (XBB.1.5-like)  2689001       True
# ERR10937945    CH.1.1.3     Omicron (BA.2-like)  2689002       True
# ERR10937969    CH.1.1.3     Omicron (BA.2-like)  2689003       True
#
#              is_recombinant  num_mutations  max_descendant_samples       date
# sample_id
# SRR11772659           False              1                     255 2020-01-19
# SRR11397727           False              0                       1 2020-01-24
# SRR11397730           False              0                       1 2020-01-24
# SRR11597198           False              0                       1 2020-01-25
# SRR11597221           False              0                       1 2020-01-25
# ...                     ...            ...                     ...        ...
# ERR10937847           False              0                       1 2023-02-20
# ERR10937891           False              0                       1 2023-02-20
# ERR10937893           False              0                       1 2023-02-20
# ERR10937945           False              0                       1 2023-02-20
# ERR10937969           False              0                       1 2023-02-20
#
# [2482157 rows x 8 columns]

# %%
df = df.join(ds.metadata.as_dataframe(["Viridian_pangolin", "Viridian_scorpio", "Viridian_pangolin_1.29", "Viridian_scorpio_1.29"]))
df
# Out:
#                   pango                 scorpio  node_id  is_sample  \
# sample_id
# SRR11772659           A                       .        2       True
# SRR11397727           B                       .        3       True
# SRR11397730           B                       .        4       True
# SRR11597198           A                       .        6       True
# SRR11597221           A                       .        7       True
# ...                 ...                     ...      ...        ...
# ERR10937847     XBB.1.5  Omicron (XBB.1.5-like)  2688999       True
# ERR10937891  XBB.1.5.62  Omicron (XBB.1.5-like)  2689000       True
# ERR10937893        FD.1  Omicron (XBB.1.5-like)  2689001       True
# ERR10937945    CH.1.1.3     Omicron (BA.2-like)  2689002       True
# ERR10937969    CH.1.1.3     Omicron (BA.2-like)  2689003       True
#
#              is_recombinant  num_mutations  max_descendant_samples       date  \
# sample_id
# SRR11772659           False              1                     255 2020-01-19
# SRR11397727           False              0                       1 2020-01-24
# SRR11397730           False              0                       1 2020-01-24
# SRR11597198           False              0                       1 2020-01-25
# SRR11597221           False              0                       1 2020-01-25
# ...                     ...            ...                     ...        ...
# ERR10937847           False              0                       1 2023-02-20
# ERR10937891           False              0                       1 2023-02-20
# ERR10937893           False              0                       1 2023-02-20
# ERR10937945           False              0                       1 2023-02-20
# ERR10937969           False              0                       1 2023-02-20
#
#             Viridian_pangolin        Viridian_scorpio Viridian_pangolin_1.29  \
# sample_id
# SRR11772659                 A                       .                      A
# SRR11397727                 B                       .                      B
# SRR11397730                 B                       .                      B
# SRR11597198                 A                       .                      A
# SRR11597221                 A                       .                      A
# ...                       ...                     ...                    ...
# ERR10937847           XBB.1.5  Omicron (XBB.1.5-like)                XBB.1.5
# ERR10937891        XBB.1.5.62  Omicron (XBB.1.5-like)             XBB.1.5.62
# ERR10937893              FD.1  Omicron (XBB.1.5-like)                   FD.1
# ERR10937945          CH.1.1.3     Omicron (BA.2-like)               CH.1.1.3
# ERR10937969          CH.1.1.3     Omicron (BA.2-like)               CH.1.1.3
#
#               Viridian_scorpio_1.29
# sample_id
# SRR11772659                       .
# SRR11397727                       .
# SRR11397730                       .
# SRR11597198                       .
# SRR11597221                       .
# ...                             ...
# ERR10937847  Omicron (XBB.1.5-like)
# ERR10937891  Omicron (XBB.1.5-like)
# ERR10937893  Omicron (XBB.1.5-like)
# ERR10937945     Omicron (BA.2-like)
# ERR10937969     Omicron (BA.2-like)
#
# [2482157 rows x 12 columns]

# %%
diff = np.sum(df["pango"] != df["Viridian_pangolin_1.29"]) 
diff
# Out:
# np.int64(8293)

# %%
f"{diff/len(df) * 100:.2f}"
# Out:
# '0.33'

# %%
diff = np.sum(df["Viridian_pangolin"] != df["Viridian_pangolin_1.29"]) 
diff
# Out:
# np.int64(6588)

# %%
f"{diff/len(df) * 100:.2f}"
# Out:
# '0.27'

# %%
np.sum(df["scorpio"] != df["Viridian_scorpio"])
# Out:
# np.int64(727)

# %%
np.sum(df["Viridian_scorpio"] != df["Viridian_scorpio_1.29"])
# Out:
# np.int64(0)

# %%
df[df["scorpio"] != df["Viridian_scorpio_1.29"]][["scorpio", "Viridian_scorpio_1.29"]]
# Out:
#                                    scorpio   Viridian_scorpio_1.29
# sample_id
# SRR14389522                Zeta (P.2-like)                       .
# SRR16617944                Zeta (P.2-like)                       .
# ERR5946784   Delta (B.1.617.2-like) +K417N       Delta (AY.4-like)
# ERR8516089   Delta (B.1.617.2-like) +K417N  Delta (B.1.617.2-like)
# ERR6165703               Delta (AY.4-like)  Delta (B.1.617.2-like)
# ...                                    ...                     ...
# SRR23601085             Omicron (XBB-like)  Omicron (XBB.1.5-like)
# SRR23601164             Omicron (XBB-like)  Omicron (XBB.1.5-like)
# SRR23601292             Omicron (XBB-like)  Omicron (XBB.1.5-like)
# SRR23601180             Omicron (XBB-like)  Omicron (XBB.1.5-like)
# SRR23601370             Omicron (XBB-like)  Omicron (XBB.1.5-like)
#
# [727 rows x 2 columns]
