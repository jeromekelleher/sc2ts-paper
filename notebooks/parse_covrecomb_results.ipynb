# %%
from collections import Counter
from pathlib import Path
import pandas as pd

# %%
data_dir = Path("../data")
overview_file = data_dir / "bigtable_pangodesig.csv"
overview_df = pd.read_csv(overview_file)
pangos = overview_df.pango
len(pangos)
# Out:
# 60

# %% [markdown]
# #### Independent recombination events

# %%
# Get the 1451 independent recombination events from the CovRecomb paper, and
# subset to the ones corresponding to the Pango X labels ("X" series).
# NOTE: No XBB.* or other X?.*
table_s4_url = "https://raw.githubusercontent.com/wuaipinglab/CovRecomb/refs/heads/main/CovRecomb-Global-Version/supplementary%20tables/TableS4.csv"
table_s4_df = pd.read_csv(table_s4_url)
table_s4_df = table_s4_df[table_s4_df.X_series.isin(pangos)].reset_index(drop=True)
table_s4_df.head(5)
# Out:
#                               sample_id collect_date pango_lineage lineage_X  \
# 0     hCoV-19/USA/CA-CDC-FG-008007/2021    2021/3/10            XB   B.1.631
# 1      hCoV-19/Denmark/DCGC-322560/2022     2022/1/7          BA.2    BA.1.9
# 2        hCoV-19/Venezuela/Dtt3630/2022    2022/1/22          BA.2  BA.1.1.7
# 3      hCoV-19/Denmark/DCGC-301091/2021   2021/12/30            XH    BA.1.9
# 4  hCoV-19/USA/NJ-CDC-ASC210687738/2022    2022/1/29            XM   BA.1.1*
#
#   lineage_Y                        mutation_pattern    raw_p_value  \
# 0   B.1.634                       YYYYYYYXXXXXXXXXY   1.780000e-39
# 1   BA.2.23  XXXXYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY  5.410000e-112
# 2   BA.2.9*    XXXXYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY  3.020000e-109
# 3   BA.2.9*   XXXXYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY  7.340000e-109
# 4   BA.2.23                XXXXXXXXXYYYYYYYYYYYYYYY  4.890000e-106
#
#    adjusted_p_value                                        X_mutations  \
# 0      1.440000e-36  22882_A/23604_A/23765_G/24442_T/24642_T/26158_...
# 1     9.840000e-109                      2832_G/5386_G/6513_---/8393_A
# 2     8.360000e-106                        2470_T/2832_G/5386_G/8393_A
# 3     1.620000e-105                      2832_G/5386_G/6513_---/8393_A
# 4     1.100000e-102  2470_T/2832_G/5386_G/6513_---/8393_A/11285_---...
#
#                                          Y_mutations  \
# 0  7142_G/9614_G/9693_T/9754_C/11288_---------/15...
# 1  9866_T/10198_T/10447_A/11288_---------/12880_T...
# 2  11288_---------/12880_T/15714_T/17410_T/19955_...
# 3  11288_---------/12880_T/15714_T/17410_T/19955_...
# 4  21618_T/21633_---------/21987_A/22200_G/22688_...
#
#                                     shared_mutations  \
# 0  3037_T/14408_T/21615_G/21846_T/22036_C/23403_G...
# 1  3037_T/10029_T/10449_A/14408_T/18163_G/22578_A...
# 2  3037_T/10029_T/10449_A/14408_T/18163_G/22578_A...
# 3  3037_T/10029_T/10449_A/14408_T/18163_G/22578_A...
# 4  3037_T/10029_T/10449_A/14408_T/18163_G/22578_A...
#
#                                     denovo_mutations         situation  \
# 0  1255_G/3688_T/3884_T/6633_T/15026_T/21057_T/23...   B.1.631_B.1.634
# 1  686_---------/3241_T/5924_A/27571_------------...    BA.1.9_BA.2.23
# 2  2441_A/6513_---/7081_T/13124_A/14838_T/15451_A...  BA.1.1.7_BA.2.9*
# 3                         902_C/904_A/1244_A/28435_T    BA.1.9_BA.2.9*
# 4                                            20343_C   BA.1.1*_BA.2.23
#
#           region    country  Number_of_epidemic_recombinant  \
# 0  North America        USA                            3332
# 1         Europe    Denmark                            2522
# 2  South America  Venezuela                             427
# 3         Europe    Denmark                             422
# 4  North America        USA                             390
#
#                            Geographical_distribution X_series  \
# 0  USA_2611/Mexico_509/Spain_23/Honduras_55/Guate...       XB
# 1  Denmark_22/United Kingdom_1767/Hong Kong_6/Ind...       XE
# 2  Venezuela_4/Norway_11/USA_61/Costa Rica_144/De...      XAF
# 3  Denmark_187/Finland_151/Sweden_2/Belgium_6/Cze...       XH
# 4  USA_5/Germany_220/Bahrain_1/Netherlands_17/Bel...       XM
#
#    Confidence_mean              breakpoints
# 0           0.9659  28330-28910,16466-22882
# 1           0.8517                8393-9866
# 2           0.8135               8393-11288
# 3           0.8335               8393-11288
# 4           0.9238              15240-21618

# %%
# Some Pango Xs have multiple events associated with them.
# There is typically one event that has the highest number of epidemic recombinants.
table_s4_df = table_s4_df[
    [
        "X_series",
        "lineage_X",
        "lineage_Y",
        "X_mutations",
        "Y_mutations",
        "mutation_pattern",
        #"situation",
        "breakpoints",
        "Number_of_epidemic_recombinant",
    ]
].sort_values(
    by=["X_series", "Number_of_epidemic_recombinant"],
    ascending=[True, False],
).reset_index(drop=True)
table_s4_df.head(5)
# Out:
#   X_series lineage_X   lineage_Y  \
# 0       XA  B.1.1.7*  B.1.177.18
# 1      XAB   BA.1.1*     BA.2.31
# 2      XAF  BA.1.1.7     BA.2.9*
# 3      XAF  BA.1.1.7     BA.2.9*
# 4      XAG   BA.1.1*     BA.2.9*
#
#                                          X_mutations  \
# 0  21765_------/21992_---/23063_T/23271_A/23604_A...
# 1               2470_T/2832_G/5386_G/6513_---/8393_A
# 2                        2470_T/2832_G/5386_G/8393_A
# 3                        2470_T/2832_G/5386_G/8393_A
# 4                      2470_T/2832_G/5386_G/6513_---
#
#                                          Y_mutations  \
# 0                       445_C/6286_T/10323_G/21255_C
# 1  11288_---------/12880_T/15714_T/17410_T/19955_...
# 2  11288_---------/12880_T/15714_T/17410_T/19955_...
# 3  11288_---------/12880_T/15714_T/17410_T/21618_...
# 4  9534_T/9866_T/10198_T/10447_A/11288_---------/...
#
#                        mutation_pattern  breakpoints  \
# 0                YYYYXXXXXXXXXXXXXXXXXX  21255-21765
# 1                  XXXXXYYYYYYYYYYYYYYY   8393-11288
# 2  XXXXYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY   8393-11288
# 3        XXXXYYYYYYYYYYYYYYYYYYYYYYYYYY   8393-11288
# 4            XXXXYYYYYYYYYYYYYYYYYYYYYY    6513-9534
#
#    Number_of_epidemic_recombinant
# 0                              43
# 1                               5
# 2                             427
# 3                               2
# 4                              17

# %%
def _get_breakpoints(mut_patt, left):
    pos = [x.split("_")[0] for x in mut_patt.split("/")]
    if left:
        return int(pos[0])
    return int(pos[-1])

# %%
data = []
for _, row in table_s4_df.iterrows():
    num_XY = row["mutation_pattern"].count("XY")
    num_YX = row["mutation_pattern"].count("YX")
    if num_XY + num_YX == 1:
        # NOTE: X and Y do not mean left parent and right parent, respectively.
        if num_XY == 1:
            parent_left_pango = row["lineage_X"]
            parent_right_pango = row["lineage_Y"]
            interval_left = _get_breakpoints(row["X_mutations"], left=False)
            interval_right = _get_breakpoints(row["Y_mutations"], left=True)
        else:
            parent_left_pango = row["lineage_Y"]
            parent_right_pango = row["lineage_X"]
            interval_left = _get_breakpoints(row["Y_mutations"], left=False)
            interval_right = _get_breakpoints(row["X_mutations"], left=True)
        data.append(
            {
                "pango": row["X_series"],
                "is_in_results": "TRUE",
                "type": "simple",
                "parent_left_pango": parent_left_pango,
                "parent_right_pango": parent_right_pango,
                "interval_left": str(interval_left),
                "interval_right": str(interval_right + 1),   # NOTE: Make right-exclusive.
                "num_epidemic_recombs": row["Number_of_epidemic_recombinant"],
            }
        )
    else:
        data.append(
            {
                "pango": row["X_series"],
                "is_in_results": "TRUE",
                "type": "complex",
                "parent_left_pango": "n/a",
                "parent_right_pango": "n/a",
                "interval_left": "n/a",
                "interval_right": "n/a",
                "num_epidemic_recombs": row["Number_of_epidemic_recombinant"],
            }
        )
table_s4_df = pd.DataFrame(data)
table_s4_df
# Out:
#    pango is_in_results     type parent_left_pango parent_right_pango  \
# 0     XA          TRUE   simple        B.1.177.18           B.1.1.7*
# 1    XAB          TRUE   simple           BA.1.1*            BA.2.31
# 2    XAF          TRUE   simple          BA.1.1.7            BA.2.9*
# 3    XAF          TRUE   simple          BA.1.1.7            BA.2.9*
# 4    XAG          TRUE   simple           BA.1.1*            BA.2.9*
# 5    XAJ          TRUE  complex               n/a                n/a
# 6    XAJ          TRUE  complex               n/a                n/a
# 7    XAJ          TRUE  complex               n/a                n/a
# 8    XAL          TRUE   simple           BA.1.1*            BA.2.23
# 9    XAM          TRUE   simple           BA.1.1*            BA.2.9*
# 10    XB          TRUE  complex               n/a                n/a
# 11    XB          TRUE  complex               n/a                n/a
# 12   XBB          TRUE   simple              BJ.1           BM.1.1.1
# 13   XBB          TRUE   simple              BJ.1           BM.1.1.1
# 14   XBB          TRUE   simple              BJ.1           BM.1.1.1
# 15   XBB          TRUE   simple              BJ.1           BM.1.1.1
# 16   XBB          TRUE   simple              BJ.1           BM.1.1.1
# 17   XBD          TRUE   simple        BA.2.75.2*            BF.3.1*
# 18   XBD          TRUE   simple        BA.2.75.2*            BF.3.1*
# 19   XBD          TRUE   simple        BA.2.75.2*            BF.3.1*
# 20   XBE          TRUE   simple          BA.5.2.2           BE.4.1.1
# 21   XBF          TRUE   simple           BM.1.1*               BQ.2
# 22   XBJ          TRUE   simple             CM.2*            BA.5.2*
# 23   XBJ          TRUE   simple             CM.2*            BA.5.2*
# 24    XC          TRUE   simple           AY.29.1           B.1.1.7*
# 25    XE          TRUE   simple            BA.1.9            BA.2.23
# 26    XE          TRUE   simple            BA.1.9            BA.2.23
# 27    XH          TRUE   simple            BA.1.9            BA.2.9*
# 28    XH          TRUE   simple            BA.1.9            BA.2.9*
# 29    XH          TRUE   simple            BA.1.9            BA.2.9*
# 30    XJ          TRUE   simple            BA.1.9            BA.2.9*
# 31    XM          TRUE   simple           BA.1.1*            BA.2.23
# 32    XM          TRUE   simple           BA.1.1*            BA.2.23
# 33    XM          TRUE   simple           BA.1.1*            BA.2.23
# 34    XM          TRUE   simple           BA.1.1*            BA.2.23
# 35    XM          TRUE   simple           BA.1.1*            BA.2.23
# 36    XM          TRUE   simple           BA.1.1*            BA.2.23
# 37    XS          TRUE   simple           AY.112*            BA.1.1*
# 38    XS          TRUE   simple           AY.112*            BA.1.1*
# 39    XY          TRUE   simple           BA.1.1*            BA.2.9*
#
#    interval_left interval_right  num_epidemic_recombs
# 0          21255          21766                    43
# 1           8393          11289                     5
# 2           8393          11289                   427
# 3           8393          11289                     2
# 4           6513           9535                    17
# 5            n/a            n/a                    43
# 6            n/a            n/a                    15
# 7            n/a            n/a                     6
# 8          15240          19956                     2
# 9           6513           9345                    12
# 10           n/a            n/a                  3332
# 11           n/a            n/a                     2
# 12         22109          22675                    97
# 13         22109          22201                     7
# 14         22200          22787                     4
# 15         22200          23020                     3
# 16         22200          22675                     2
# 17         23019          24621                   268
# 18         22599          24621                     3
# 19         23019          24621                     2
# 20         21765          22600                   376
# 21         23075          26530                     8
# 22         23013          26530                   134
# 23         22332          26530                     2
# 24         26767          27973                    24
# 25          8393           9867                  2522
# 26          8393          11289                    15
# 27          8393          11289                   422
# 28          8393          11289                     5
# 29          8393          11289                     3
# 30         13195          15715                    73
# 31         15240          21619                   390
# 32         15240          19956                    35
# 33         13195          19956                    24
# 34         22194          22689                     8
# 35         22194          22689                     4
# 36         15240          19956                     3
# 37          9053          10450                    13
# 38          9053          10450                     2
# 39         15240          21619                   142

# %%
# When there are multiple events associated with the same Pango X,
# get the event with the highest number of epidemic recombinants.
idx = table_s4_df.groupby('pango')['num_epidemic_recombs'].idxmax()
table_s4_df = table_s4_df.loc[idx].reset_index(drop=True)
table_s4_df
# Out:
#    pango is_in_results     type parent_left_pango parent_right_pango  \
# 0     XA          TRUE   simple        B.1.177.18           B.1.1.7*
# 1    XAB          TRUE   simple           BA.1.1*            BA.2.31
# 2    XAF          TRUE   simple          BA.1.1.7            BA.2.9*
# 3    XAG          TRUE   simple           BA.1.1*            BA.2.9*
# 4    XAJ          TRUE  complex               n/a                n/a
# 5    XAL          TRUE   simple           BA.1.1*            BA.2.23
# 6    XAM          TRUE   simple           BA.1.1*            BA.2.9*
# 7     XB          TRUE  complex               n/a                n/a
# 8    XBB          TRUE   simple              BJ.1           BM.1.1.1
# 9    XBD          TRUE   simple        BA.2.75.2*            BF.3.1*
# 10   XBE          TRUE   simple          BA.5.2.2           BE.4.1.1
# 11   XBF          TRUE   simple           BM.1.1*               BQ.2
# 12   XBJ          TRUE   simple             CM.2*            BA.5.2*
# 13    XC          TRUE   simple           AY.29.1           B.1.1.7*
# 14    XE          TRUE   simple            BA.1.9            BA.2.23
# 15    XH          TRUE   simple            BA.1.9            BA.2.9*
# 16    XJ          TRUE   simple            BA.1.9            BA.2.9*
# 17    XM          TRUE   simple           BA.1.1*            BA.2.23
# 18    XS          TRUE   simple           AY.112*            BA.1.1*
# 19    XY          TRUE   simple           BA.1.1*            BA.2.9*
#
#    interval_left interval_right  num_epidemic_recombs
# 0          21255          21766                    43
# 1           8393          11289                     5
# 2           8393          11289                   427
# 3           6513           9535                    17
# 4            n/a            n/a                    43
# 5          15240          19956                     2
# 6           6513           9345                    12
# 7            n/a            n/a                  3332
# 8          22109          22675                    97
# 9          23019          24621                   268
# 10         21765          22600                   376
# 11         23075          26530                     8
# 12         23013          26530                   134
# 13         26767          27973                    24
# 14          8393           9867                  2522
# 15          8393          11289                   422
# 16         13195          15715                    73
# 17         15240          21619                   390
# 18          9053          10450                    13
# 19         15240          21619                   142

# %% [markdown]
# #### Other putative recombination events

# %%
recomb_url = "https://raw.githubusercontent.com/wuaipinglab/CovRecomb/refs/heads/main/CovRecomb-Global-Version/putative_recombinants/putative%20recombinants.csv"
recomb_df = pd.read_csv(recomb_url)
recomb_df.columns
# Out:
# Index(['sample_id', 'collect_date', 'pango_lineage', 'lineage_X', 'lineage_Y',
#        'mutation_pattern', 'raw_p_value', 'adjusted_p_value', 'X_mutations',
#        'Y_mutations', 'shared_mutations', 'denovo_mutations', 'region',
#        'country'],
#       dtype='object')

# %%
# NOTE: pango_lineage is the Pango assigned to the sample (from GISAID).
for p in pangos:
    num_pango_lineage = sum(recomb_df.pango_lineage == p)
    #print(p, num_pango_lineage)

# %%
data = []
for p in pangos:
    num_simple = 0
    num_complex = 0
    recomb_counts = Counter()
    for _, row in recomb_df[
        # NOTE: Lumps together XBB.* and other X?.*
        (recomb_df.pango_lineage == p) | \
        (recomb_df.pango_lineage.str.startswith(p + "."))
    ].iterrows():
        num_XY = row["mutation_pattern"].count("XY")
        num_YX = row["mutation_pattern"].count("YX")
        if num_XY + num_YX == 1:
            num_simple += 1
            # NOTE: X and Y do not mean left parent and right parent, respectively.
            if num_XY == 1:
                parent_left_pango = row["lineage_X"]
                parent_right_pango = row["lineage_Y"]
                interval_left = _get_breakpoints(row["X_mutations"], left=False)
                interval_right = _get_breakpoints(row["Y_mutations"], left=True)
            else:
                parent_left_pango = row["lineage_Y"]
                parent_right_pango = row["lineage_X"]
                interval_left = _get_breakpoints(row["Y_mutations"], left=False)
                interval_right = _get_breakpoints(row["X_mutations"], left=True)
            recomb_counts[(parent_left_pango, parent_right_pango, interval_left, interval_right)] += 1
        else:
            num_complex += 1
    # Summarise results per Pango X.
    if num_simple + num_complex == 0:
        data.append(
            {
                "pango": p,
                "is_in_results": "FALSE",
                "type": "n/a",
                "parent_left_pango": "n/a",
                "parent_right_pango": "n/a",
                "interval_left": "n/a",
                "interval_right": "n/a",
                "max_count": "n/a",
                "num_simple": num_simple,
                "num_complex": num_complex,
            }
        )
    elif num_simple >= num_complex:
        (
            most_common_parent_left,
            most_common_parent_right,
            most_common_interval_left,
            most_common_interval_right,
        ) = recomb_counts.most_common()[0][0]
        data.append(
            {
                "pango": p,
                "is_in_results": "TRUE",
                "type": "simple",
                "parent_left_pango": most_common_parent_left,
                "parent_right_pango": most_common_parent_right,
                "interval_left": str(most_common_interval_left),
                "interval_right": str(most_common_interval_right + 1),   # NOTE: Make right-exclusive.
                "max_count": max(recomb_counts.values()),    # Most common
                "num_simple": num_simple,
                "num_complex": num_complex,
            }
        )
    else:
        data.append(
            {
                "pango": p,
                "is_in_results": "TRUE",
                "type": "complex",
                "parent_left_pango": "n/a",
                "parent_right_pango": "n/a",
                "interval_left": "n/a",
                "interval_right": "n/a",
                "max_count": "n/a",
                "num_simple": num_simple,
                "num_complex": num_complex,
            }
        )
recomb_df = pd.DataFrame(data)
recomb_df
# Out:
#    pango is_in_results     type parent_left_pango parent_right_pango  \
# 0     XA          TRUE   simple        B.1.177.18           B.1.1.7*
# 1    XAA         FALSE      n/a               n/a                n/a
# 2    XAB          TRUE   simple           BA.1.1*            BA.2.31
# 3    XAC         FALSE      n/a               n/a                n/a
# 4    XAD         FALSE      n/a               n/a                n/a
# 5    XAE          TRUE   simple         BA.2.3.16          B.1.1.322
# 6    XAF          TRUE   simple          BA.1.1.7            BA.2.9*
# 7    XAG          TRUE   simple           BA.1.1*            BA.2.9*
# 8    XAH         FALSE      n/a               n/a                n/a
# 9    XAJ          TRUE  complex               n/a                n/a
# 10   XAK          TRUE  complex               n/a                n/a
# 11   XAL          TRUE   simple           BA.1.1*            BA.2.23
# 12   XAM          TRUE   simple           BA.1.1*            BA.2.9*
# 13   XAN          TRUE  complex               n/a                n/a
# 14   XAP         FALSE      n/a               n/a                n/a
# 15   XAS          TRUE   simple              BA.5            BA.2.17
# 16   XAU         FALSE      n/a               n/a                n/a
# 17   XAV         FALSE      n/a               n/a                n/a
# 18   XAY         FALSE      n/a               n/a                n/a
# 19   XAZ         FALSE      n/a               n/a                n/a
# 20    XB          TRUE  complex               n/a                n/a
# 21   XBB          TRUE   simple              BJ.1           BM.1.1.1
# 22   XBC          TRUE  complex               n/a                n/a
# 23   XBD          TRUE   simple        BA.2.75.2*            BF.3.1*
# 24   XBE          TRUE   simple          BA.5.2.2           BE.4.1.1
# 25   XBF          TRUE   simple           BM.1.1*               BQ.2
# 26   XBG         FALSE      n/a               n/a                n/a
# 27   XBH         FALSE      n/a               n/a                n/a
# 28   XBJ          TRUE   simple             CM.2*            BA.5.2*
# 29   XBK         FALSE      n/a               n/a                n/a
# 30   XBL         FALSE      n/a               n/a                n/a
# 31   XBM         FALSE      n/a               n/a                n/a
# 32   XBN         FALSE      n/a               n/a                n/a
# 33   XBP         FALSE      n/a               n/a                n/a
# 34   XBQ         FALSE      n/a               n/a                n/a
# 35   XBR         FALSE      n/a               n/a                n/a
# 36   XBS         FALSE      n/a               n/a                n/a
# 37   XBT         FALSE      n/a               n/a                n/a
# 38   XBU         FALSE      n/a               n/a                n/a
# 39   XBW         FALSE      n/a               n/a                n/a
# 40   XBZ         FALSE      n/a               n/a                n/a
# 41    XC          TRUE   simple           AY.29.1           B.1.1.7*
# 42   XCA         FALSE      n/a               n/a                n/a
# 43   XCG         FALSE      n/a               n/a                n/a
# 44    XE          TRUE   simple            BA.1.9            BA.2.23
# 45    XF         FALSE      n/a               n/a                n/a
# 46    XG         FALSE      n/a               n/a                n/a
# 47    XH          TRUE   simple            BA.1.9            BA.2.9*
# 48    XJ          TRUE   simple            BA.1.9            BA.2.9*
# 49    XL         FALSE      n/a               n/a                n/a
# 50    XM          TRUE   simple           BA.1.1*            BA.2.23
# 51    XN          TRUE   simple         BA.2.3.16            BA.2.69
# 52    XP         FALSE      n/a               n/a                n/a
# 53    XQ         FALSE      n/a               n/a                n/a
# 54    XR         FALSE      n/a               n/a                n/a
# 55    XS          TRUE   simple           AY.112*            BA.1.1*
# 56    XU         FALSE      n/a               n/a                n/a
# 57    XW         FALSE      n/a               n/a                n/a
# 58    XY          TRUE   simple           BA.1.1*            BA.2.9*
# 59    XZ         FALSE      n/a               n/a                n/a
#
#    interval_left interval_right max_count  num_simple  num_complex
# 0          21255          21766        43          43            0
# 1            n/a            n/a       n/a           0            0
# 2           6513           9345         2           3            0
# 3            n/a            n/a       n/a           0            0
# 4            n/a            n/a       n/a           0            0
# 5          27807          28878         3           3            0
# 6           8393          11289       277         292            0
# 7           6513           9345        24          38            0
# 8            n/a            n/a       n/a           0            0
# 9            n/a            n/a       n/a           1           76
# 10           n/a            n/a       n/a           0           28
# 11         15240          19956        94         118            5
# 12          6513           9345        11          12            0
# 13           n/a            n/a       n/a           6           13
# 14           n/a            n/a       n/a           0            0
# 15         23075          25417         4           4            2
# 16           n/a            n/a       n/a           0            0
# 17           n/a            n/a       n/a           0            0
# 18           n/a            n/a       n/a           0            0
# 19           n/a            n/a       n/a           0            0
# 20           n/a            n/a       n/a          52         3325
# 21         22200          22675     46928       51823          758
# 22           n/a            n/a       n/a           5          159
# 23         23019          24621       269         273            0
# 24         21765          22600       149         156            0
# 25         23075          26530         8           8            0
# 26           n/a            n/a       n/a           0            0
# 27           n/a            n/a       n/a           0            0
# 28         23013          26530       124         134            0
# 29           n/a            n/a       n/a           0            0
# 30           n/a            n/a       n/a           0            0
# 31           n/a            n/a       n/a           0            0
# 32           n/a            n/a       n/a           0            0
# 33           n/a            n/a       n/a           0            0
# 34           n/a            n/a       n/a           0            0
# 35           n/a            n/a       n/a           0            0
# 36           n/a            n/a       n/a           0            0
# 37           n/a            n/a       n/a           0            0
# 38           n/a            n/a       n/a           0            0
# 39           n/a            n/a       n/a           0            0
# 40           n/a            n/a       n/a           0            0
# 41         26767          27973        24          24            0
# 42           n/a            n/a       n/a           0            0
# 43           n/a            n/a       n/a           0            0
# 44          8393          11289      2210        2408           17
# 45           n/a            n/a       n/a           0            0
# 46           n/a            n/a       n/a           0            0
# 47          8393          11289       148         159            0
# 48         13195          15715       219         247            3
# 49           n/a            n/a       n/a           0            0
# 50         15240          19956       273         464            6
# 51         22688          22793        11          11            0
# 52           n/a            n/a       n/a           0            0
# 53           n/a            n/a       n/a           0            0
# 54           n/a            n/a       n/a           0            0
# 55          9053          10450        12          13            0
# 56           n/a            n/a       n/a           0            0
# 57           n/a            n/a       n/a           0            0
# 58         11537          12881        88         117            1
# 59           n/a            n/a       n/a           0            0

# %% [markdown]
# #### Merging the results above

# %%
# NOTE: The breakpoint intervals have been adjusted to be right-exclusive.
data = []
for p in pangos:
    if any(table_s4_df.pango == p):
        row = table_s4_df[table_s4_df.pango == p]
    else:
        row = recomb_df[recomb_df.pango == p]
    data.append(
        {
            "pango": row["pango"].to_list()[0],
            "is_in_results": row["is_in_results"].to_list()[0],
            "type": row["type"].to_list()[0],
            "parent_left_pango": row["parent_left_pango"].to_list()[0],
            "parent_right_pango": row["parent_right_pango"].to_list()[0],
            "interval_left": row["interval_left"].to_list()[0],
            "interval_right": row["interval_right"].to_list()[0],
        }
    )
merged_df = pd.DataFrame(data)
merged_df
# Out:
#    pango is_in_results     type parent_left_pango parent_right_pango  \
# 0     XA          TRUE   simple        B.1.177.18           B.1.1.7*
# 1    XAA         FALSE      n/a               n/a                n/a
# 2    XAB          TRUE   simple           BA.1.1*            BA.2.31
# 3    XAC         FALSE      n/a               n/a                n/a
# 4    XAD         FALSE      n/a               n/a                n/a
# 5    XAE          TRUE   simple         BA.2.3.16          B.1.1.322
# 6    XAF          TRUE   simple          BA.1.1.7            BA.2.9*
# 7    XAG          TRUE   simple           BA.1.1*            BA.2.9*
# 8    XAH         FALSE      n/a               n/a                n/a
# 9    XAJ          TRUE  complex               n/a                n/a
# 10   XAK          TRUE  complex               n/a                n/a
# 11   XAL          TRUE   simple           BA.1.1*            BA.2.23
# 12   XAM          TRUE   simple           BA.1.1*            BA.2.9*
# 13   XAN          TRUE  complex               n/a                n/a
# 14   XAP         FALSE      n/a               n/a                n/a
# 15   XAS          TRUE   simple              BA.5            BA.2.17
# 16   XAU         FALSE      n/a               n/a                n/a
# 17   XAV         FALSE      n/a               n/a                n/a
# 18   XAY         FALSE      n/a               n/a                n/a
# 19   XAZ         FALSE      n/a               n/a                n/a
# 20    XB          TRUE  complex               n/a                n/a
# 21   XBB          TRUE   simple              BJ.1           BM.1.1.1
# 22   XBC          TRUE  complex               n/a                n/a
# 23   XBD          TRUE   simple        BA.2.75.2*            BF.3.1*
# 24   XBE          TRUE   simple          BA.5.2.2           BE.4.1.1
# 25   XBF          TRUE   simple           BM.1.1*               BQ.2
# 26   XBG         FALSE      n/a               n/a                n/a
# 27   XBH         FALSE      n/a               n/a                n/a
# 28   XBJ          TRUE   simple             CM.2*            BA.5.2*
# 29   XBK         FALSE      n/a               n/a                n/a
# 30   XBL         FALSE      n/a               n/a                n/a
# 31   XBM         FALSE      n/a               n/a                n/a
# 32   XBN         FALSE      n/a               n/a                n/a
# 33   XBP         FALSE      n/a               n/a                n/a
# 34   XBQ         FALSE      n/a               n/a                n/a
# 35   XBR         FALSE      n/a               n/a                n/a
# 36   XBS         FALSE      n/a               n/a                n/a
# 37   XBT         FALSE      n/a               n/a                n/a
# 38   XBU         FALSE      n/a               n/a                n/a
# 39   XBW         FALSE      n/a               n/a                n/a
# 40   XBZ         FALSE      n/a               n/a                n/a
# 41    XC          TRUE   simple           AY.29.1           B.1.1.7*
# 42   XCA         FALSE      n/a               n/a                n/a
# 43   XCG         FALSE      n/a               n/a                n/a
# 44    XE          TRUE   simple            BA.1.9            BA.2.23
# 45    XF         FALSE      n/a               n/a                n/a
# 46    XG         FALSE      n/a               n/a                n/a
# 47    XH          TRUE   simple            BA.1.9            BA.2.9*
# 48    XJ          TRUE   simple            BA.1.9            BA.2.9*
# 49    XL         FALSE      n/a               n/a                n/a
# 50    XM          TRUE   simple           BA.1.1*            BA.2.23
# 51    XN          TRUE   simple         BA.2.3.16            BA.2.69
# 52    XP         FALSE      n/a               n/a                n/a
# 53    XQ         FALSE      n/a               n/a                n/a
# 54    XR         FALSE      n/a               n/a                n/a
# 55    XS          TRUE   simple           AY.112*            BA.1.1*
# 56    XU         FALSE      n/a               n/a                n/a
# 57    XW         FALSE      n/a               n/a                n/a
# 58    XY          TRUE   simple           BA.1.1*            BA.2.9*
# 59    XZ         FALSE      n/a               n/a                n/a
#
#    interval_left interval_right
# 0          21255          21766
# 1            n/a            n/a
# 2           8393          11289
# 3            n/a            n/a
# 4            n/a            n/a
# 5          27807          28878
# 6           8393          11289
# 7           6513           9535
# 8            n/a            n/a
# 9            n/a            n/a
# 10           n/a            n/a
# 11         15240          19956
# 12          6513           9345
# 13           n/a            n/a
# 14           n/a            n/a
# 15         23075          25417
# 16           n/a            n/a
# 17           n/a            n/a
# 18           n/a            n/a
# 19           n/a            n/a
# 20           n/a            n/a
# 21         22109          22675
# 22           n/a            n/a
# 23         23019          24621
# 24         21765          22600
# 25         23075          26530
# 26           n/a            n/a
# 27           n/a            n/a
# 28         23013          26530
# 29           n/a            n/a
# 30           n/a            n/a
# 31           n/a            n/a
# 32           n/a            n/a
# 33           n/a            n/a
# 34           n/a            n/a
# 35           n/a            n/a
# 36           n/a            n/a
# 37           n/a            n/a
# 38           n/a            n/a
# 39           n/a            n/a
# 40           n/a            n/a
# 41         26767          27973
# 42           n/a            n/a
# 43           n/a            n/a
# 44          8393           9867
# 45           n/a            n/a
# 46           n/a            n/a
# 47          8393          11289
# 48         13195          15715
# 49           n/a            n/a
# 50         15240          21619
# 51         22688          22793
# 52           n/a            n/a
# 53           n/a            n/a
# 54           n/a            n/a
# 55          9053          10450
# 56           n/a            n/a
# 57           n/a            n/a
# 58         15240          21619
# 59           n/a            n/a

# %%
csv_file = data_dir / "bigtable_covrecomb.csv"
merged_df.to_csv(csv_file, sep=",", index=False)
