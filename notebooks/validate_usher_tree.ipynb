# %% [markdown]
# ## Validating the tskit Usher tree conversion
#
# In this notebook we check that the tskit encoding of the full Usher tree for the Viridian data is an accurate reflection of the data. We check that the node metadata is maintained correctly (and can be joined with the sc2ts representation of the Viridian dataset) and that we round-trip the alignment data correctly.

# %%
import tskit
import tszip
import numpy as np
import pandas as pd
import sc2ts

# %%
# %%time
ts = tszip.load("../data/usher_viridian_v1.0.trees.tsz")
# Out:
# CPU times: user 871 ms, sys: 198 ms, total: 1.07 s
# Wall time: 847 ms

# %%
ts
# Out:
#         <div>
#             <style>
#                 .tskit-table thead tr th {text-align: left;padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td {padding: 0.5em 0.5em;}
#                 .tskit-table tbody tr td:first-of-type {text-align: left;}
#                 .tskit-details-label {vertical-align: top; padding-right:5px;}
#                 .tskit-table-set {display: inline-flex;flex-wrap: wrap;margin: -12px 0 0 -12px;width: calc(100% + 12px);}
#                 .tskit-table-set-table {margin: 12px 0 0 12px;}
#                 details {display: inline-block;}
#                 summary {cursor: pointer; outline: 0; display: list-item;}
#             </style>
#             <div class="tskit-table-set">
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="padding:0;line-height:21px;">
#                                     <img style="height: 32px;display: inline-block;padding: 3px 5px 3px 0;" src="https://raw.githubusercontent.com/tskit-dev/administrative/main/tskit_logo.svg"/>
#                                     <a target="_blank" href="https://tskit.dev/tskit/docs/latest/python-api.html#the-treesequence-class"> Tree Sequence </a>
#                                 </th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             <tr><td>Trees</td><td>1</td></tr>
#                             <tr><td>Sequence Length</td><td>29 904</td></tr>
#                             <tr><td>Time Units</td><td>uncalibrated</td></tr>
#                             <tr><td>Sample Nodes</td><td>4 471 579</td></tr>
#                             <tr><td>Total Size</td><td>522.1 MiB</td></tr>
#                             <tr>
#                                 <td>Metadata</td><td style="text-align: left;">
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details open>
#                     <summary>dict</summary>
#                     time_zero_date: 2024-06-06<br/>
#                 </details>
#             </div>
#             </td>
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th style="line-height:21px;">Table</th>
#                                 <th>Rows</th>
#                                 <th>Size</th>
#                                 <th>Has Metadata</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#             <tr>
#                 <td>Edges</td>
#                 <td>5 345 018</td>
#                 <td>163.1 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Individuals</td>
#                 <td>0</td>
#                 <td>24 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Migrations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Mutations</td>
#                 <td>3 364 841</td>
#                 <td>118.7 MiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Nodes</td>
#                 <td>5 345 019</td>
#                 <td>198.8 MiB</td>
#                 <td style="text-align: center;">
#                     ✅
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Populations</td>
#                 <td>0</td>
#                 <td>8 Bytes</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Provenances</td>
#                 <td>2</td>
#                 <td>1.2 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#             <tr>
#                 <td>Sites</td>
#                 <td>27 508</td>
#                 <td>671.6 KiB</td>
#                 <td style="text-align: center;">
#
#                 </td>
#             </tr>
#
#                         </tbody>
#                     </table>
#                 </div>
#                 <div class="tskit-table-set-table">
#                     <table class="tskit-table">
#                         <thead>
#                             <tr>
#                                 <th>Provenance Timestamp</th>
#                                 <th>Software Name</th>
#                                 <th>Version</th>
#                                 <th>Command</th>
#                                 <th>Full record</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <td>12 August, 2025 at 03:26:34 PM</td>
#                     <td>sc2ts</td>
#                     <td>0.0.4.dev676+g1d501ae30</td>
#                     <td>minimise_metadata</td>
#                     <td>
#                         <details>
#                             <summary>Details</summary>
#
#             <div>
#                 <span class="tskit-details-label"></span>
#                 <details >
#                     <summary>dict</summary>
#                     schema_version: 1.0.0<br/>
#             <div>
#                 <span class="tskit-details-label">software:</span>
#                 <details >
#                     <summary>dict</summary>
#                     name: sc2ts<br/>version: 0.0.4.dev676+g1d501ae30<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">parameters:</span>
#                 <details >
#                     <summary>dict</summary>
#                     command: minimise_metadata<br/>
#             <div>
#                 <span class="tskit-details-label">field_mapping:</span>
#                 <details >
#                     <summary>dict</summary>
#                     strain: sample_id<br/>
#                 </details>
#             </div>
#             <br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">environment:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">os:</span>
#                 <details >
#                     <summary>dict</summary>
#                     system: Linux<br/>node: holly<br/>release: 5.10.0-24-amd64<br/>version: #1 SMP Debian 5.10.179-5<br/>(2023-08-08)<br/>machine: x86_64<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">python:</span>
#                 <details >
#                     <summary>dict</summary>
#                     implementation: CPython<br/>version: 3.12.11<br/>
#                 </details>
#             </div>
#             <br/>
#             <div>
#                 <span class="tskit-details-label">libraries:</span>
#                 <details >
#                     <summary>dict</summary>
#
#             <div>
#                 <span class="tskit-details-label">kastore:</span>
#                 <details >
#                     <summary>dict</summary>
#                     version: 2.1.1<br/>
#                 </details>
#             </div>

# %% [markdown]
# We can use some utility functions in sc2ts to get dataframes summarising the nodes and mutations.
#
# These use some numba-compiled code to compute inheritance statistics, which takes a few seconds to compile the first  time its run.

# %%
 # %%time
df_nodes = sc2ts.node_data(ts)
# Out:
# CPU times: user 1.2 s, sys: 376 ms, total: 1.58 s
# Wall time: 1.58 s

# %%
# %%time
df_muts = sc2ts.mutation_data(ts)
# Out:
# CPU times: user 666 ms, sys: 139 ms, total: 806 ms
# Wall time: 805 ms

# %%
df_muts
# Out:
#          mutation_id  position  parent     node inherited_state derived_state  \
# 0                  0       267      -1  1235535               T             A
# 1                  1       267      -1  5297533               T             G
# 2                  2       269      -1   246856               G             A
# 3                  3       269      -1  2677518               G             A
# 4                  4       269      -1  4780608               G             A
# ...              ...       ...     ...      ...             ...           ...
# 3364836      3364836     29671      -1  4571321               A             G
# 3364837      3364837     29671      -1  4525231               A             T
# 3364838      3364838     29671      -1  4622571               A             G
# 3364839      3364839     29671      -1  4520611               A             T
# 3364840      3364840     29671      -1  2532777               A             G
#
#               date  num_descendants  num_inheritors
# 0       2024-06-06                1               1
# 1       2024-06-06                1               1
# 2       2024-06-01               12              12
# 3       2024-06-01               75              75
# 4       2024-06-01               26              26
# ...            ...              ...             ...
# 3364836 2024-06-06                1               1
# 3364837 2024-06-06                1               1
# 3364838 2024-06-06                1               1
# 3364839 2024-06-06                1               1
# 3364840 2024-06-06                1               1
#
# [3364841 rows x 9 columns]

# %%
df_nodes
# Out:
#            sample_id  node_id  is_sample  is_recombinant  num_mutations  \
# 0         ERR4085584        0       True           False              0
# 1         ERR4086315        1       True           False              0
# 2         ERR4091746        2       True           False              0
# 3         ERR4165155        3       True           False              0
# 4         ERR4204267        4       True           False              0
# ...              ...      ...        ...             ...            ...
# 5345014  SRR21886505  5345014       True           False              5
# 5345015  node_763111  5345015      False           False              1
# 5345016  SRR21635465  5345016       True           False              0
# 5345017  node_763112  5345017      False           False              1
# 5345018  SRR21795271  5345018       True           False              0
#
#          max_descendant_samples       date
# 0                             1 2024-06-06
# 1                             1 2024-06-06
# 2                             1 2024-06-06
# 3                             1 2024-06-06
# 4                             1 2024-06-06
# ...                         ...        ...
# 5345014                       1 2024-06-06
# 5345015                       3 2024-06-04
# 5345016                       1 2024-06-06
# 5345017                       2 2024-06-05
# 5345018                       1 2024-06-06
#
# [5345019 rows x 7 columns]

# %%
df_samples = df_nodes[df_nodes.is_sample].set_index("sample_id")

# %% [markdown]
# Now load the full Viridian dataset of MAFFT alignments and metadata stored in [VCF Zarr format](https://academic.oup.com/gigascience/article/doi/10.1093/gigascience/giaf049/8154315). The sc2ts.Data object provides a wrapper for this and some handy access methods.

# %%
# %%time
ds = sc2ts.Dataset("../data/viridian_mafft_2024-10-14_v1.vcz.zip")
ds
# Out:
# Dataset at ../data/viridian_mafft_2024-10-14_v1.vcz.zip with 4484157 samples, 29903 variants, and 30 metadata fields. See ds.metadata.field_descriptors() for a description of the fields.

# %%
ds.metadata.field_descriptors()
# Out:
#                            dtype  \
# field
# Artic_primer_version      object
# Collection_date           object
# Country                   object
# Date_tree                 object
# Date_tree_order           object
# Experiment                object
# First_created             object
# Genbank_N                  int16
# Genbank_accession         object
# Genbank_other_runs        object
# Genbank_pangolin          object
# Genbank_scorpio           object
# Genbank_tree_name         object
# In_Viridian_tree            bool
# In_intersection             bool
# In_may_2024_preprint        bool
# Platform                  object
# Region                    object
# Run_count                   int8
# Sample                    object
# Study                     object
# Viridian_N                 int16
# Viridian_amplicon_scheme  object
# Viridian_cons_het           int8
# Viridian_cons_len          int16
# Viridian_pangolin         object
# Viridian_pangolin_1.29    object
# Viridian_result           object
# Viridian_scorpio          object
# Viridian_scorpio_1.29     object
#
#                                                                 description
# field
# Artic_primer_version      If known, the ARTIC primer scheme from ENA met...
# Collection_date                           collection_date from ENA metadata
# Country                   Country from ENA metadata. If ':' was in the e...
# Date_tree                 A consensus date, using up 3 sources of data f...
# Date_tree_order           This helped define the order in which the samp...
# Experiment                           experiment_accession from ENA metadata
# First_created                           first_created from the ENA metadata
# Genbank_N                 Number of Ns in the GenBank consensus sequence...
# Genbank_accession             This is the GenBank accession of the assembly
# Genbank_other_runs        Any other run accessions associated with the G...
# Genbank_pangolin          Pangolin call from the GenBank consensus seque...
# Genbank_scorpio           Scorpio call from the GenBank consensus sequen...
# Genbank_tree_name                    Name of the sample in the GenBank tree
# In_Viridian_tree          'T' or 'F' to indicate if the sample is in the...
# In_intersection           'T' or 'F' to indicate if the sample is in the...
# In_may_2024_preprint      Whether or not this run was in the May 2024 pr...
# Platform                              instrument_platform from ENA metadata
# Region                    Region from ENA metadata, if present. If ':' w...
# Run_count                      The number of runs from the sample accession
# Sample                                   sample_accession from ENA metadata
# Study                                     study_accession from ENA metadata
# Viridian_N                Number of Ns in the viridian consensus sequenc...
# Viridian_amplicon_scheme                 Amplicon scheme called by Viridian
# Viridian_cons_het
# Viridian_cons_len         Length of the Viridian consensus sequence Viri...
# Viridian_pangolin         Pangolin call from the Viridian consensus sequ...
# Viridian_pangolin_1.29    Pangolin call from the Viridian consensus sequ...
# Viridian_result           This is 'PASS' if Viridian finished and made a...
# Viridian_scorpio          Scorpio call from the Viridian consensus seque...
# Viridian_scorpio_1.29     Scorpio call from the Viridian consensus seque...

# %% [markdown]
# Do a join of this to the samples dataframe so what we can check that the metadata lines up appropriately.

# %%
# %%time
df_samples = df_samples.join(ds.metadata.as_dataframe(["Date_tree", "Viridian_pangolin_1.29"]))
df_samples
# Out:
# CPU times: user 6.52 s, sys: 432 ms, total: 6.95 s
# Wall time: 6.98 s
#              node_id  is_sample  is_recombinant  num_mutations  \
# sample_id
# ERR4085584         0       True           False              0
# ERR4086315         1       True           False              0
# ERR4091746         2       True           False              0
# ERR4165155         3       True           False              0
# ERR4204267         4       True           False              0
# ...              ...        ...             ...            ...
# SRR20933483  5345012       True           False              1
# SRR21370322  5345013       True           False              1
# SRR21886505  5345014       True           False              5
# SRR21635465  5345016       True           False              0
# SRR21795271  5345018       True           False              0
#
#              max_descendant_samples       date   Date_tree  \
# sample_id
# ERR4085584                        1 2024-06-06  2020-04-09
# ERR4086315                        1 2024-06-06  2020-04-03
# ERR4091746                        1 2024-06-06  2020-04-03
# ERR4165155                        1 2024-06-06  2020-02-26
# ERR4204267                        1 2024-06-06  2020-03-04
# ...                             ...        ...         ...
# SRR20933483                       1 2024-06-06  2022-07-11
# SRR21370322                       1 2024-06-06  2022-08-14
# SRR21886505                       1 2024-06-06  2022-09-21
# SRR21635465                       1 2024-06-06  2022-09-06
# SRR21795271                       1 2024-06-06  2022-09-12
#
#             Viridian_pangolin_1.29
# sample_id
# ERR4085584                       B
# ERR4086315                       B
# ERR4091746                       B
# ERR4165155                       B
# ERR4204267                       B
# ...                            ...
# SRR20933483               BA.5.2.1
# SRR21370322               BA.5.2.1
# SRR21886505               BA.5.2.1
# SRR21635465               BA.5.2.1
# SRR21795271               BA.5.2.1
#
# [4471579 rows x 8 columns]

# %% [markdown]
# ## Dates
#
# Not that the node times/dates on this tree are not well calibrated, and you should use the Date_tree field instead for sample dates.

# %% [markdown]
# ## Check genotype encoding

# %%
assert np.all(ts.samples() == df_samples.node_id)

# %% [markdown]
# The sc2ts dataset uses a fixed encoding of alleles, such that "A" is always 0, "C" is always 1 etc, and does not treat the reference allele specially (this is a departure from the usual conventions in VCF Zarr where allele 0 is usually the reference allele). The simplest way to compare data from a tree sequence then is to make sure that the alleles are encoded in the same way when iterating over the variants. Then, we can compare the allelic states directly using numpy operations without translating back to strings, which is *very* slow in comparison.

# %%
sc2ts.IUPAC_ALLELES
# Out:
# 'ACGT-RYSWKMBDHV.'

# %%
ds_variants = ds.variants(sample_id=df_samples.index.values, position=ts.sites_position.astype(int))
ts_variants = ts.variants(alleles=tuple("ACGT"))
from tqdm.notebook import tqdm

per_site_diffs = []
for ds_var, ts_var in tqdm(zip(ds_variants, ts_variants), total=ts.num_sites):
    assert ts_var.alleles == tuple(ds_var.alleles[:4])
    missing = ds_var.genotypes == -1
    # The IUPAC ambiguity codes in the sc2ts.IUPAC alleles are in indexes > 3.
    # We're not interested in gap characters here (which are 3)
    ambiguous = ds_var.genotypes > 3
    confident_calls = ~(missing | ambiguous)
    true_calls = ds_var.genotypes[confident_calls]
    stored = ts_var.genotypes[confident_calls]
    per_site_diffs.append(np.sum(true_calls != stored))

per_site_diffs = np.array(per_site_diffs)
# Out:
#   0%|          | 0/27508 [00:00<?, ?it/s]

# %%
non_zero = np.where(per_site_diffs != 0)
non_zero
# Out:
# (array([ 3988,  6072,  6074,  9383, 14343, 19908, 19923, 19926, 19927,
#         19929, 19932, 19933, 19937, 19942, 19944, 19945, 20150, 20493,
#         20495, 20496, 20498, 20500, 20502, 20952, 21059, 21085, 21145,
#         22050, 22143, 23119, 24547, 24593, 25361, 25475, 25606, 25718,
#         26049, 26816, 27231]),)

# %%
non_zero_pos = ts.sites_position[non_zero].astype(int)
non_zero_pos
# Out:
# array([ 4321,  6513,  6515, 10029, 15510, 21595, 21610, 21615, 21617,
#        21621, 21624, 21627, 21632, 21637, 21639, 21641, 21846, 22195,
#        22197, 22198, 22200, 22202, 22204, 22674, 22786, 22813, 22882,
#        23854, 23948, 25000, 26530, 26577, 27384, 27507, 27638, 27752,
#        28095, 28916, 29362])

# %%
non_zero_pos.shape
# Out:
# (39,)

# %%
ts.num_sites - non_zero_pos.shape[0]
# Out:
# 27469

# %% [markdown]
# We have exact matches for 27469 of the sites in the data for which we have nucleotide calls.

# %%
import collections
data = []
for var in  ds.variants(position=non_zero_pos):
    #  NB: make sure we use "N" to represent missing data
    alleles = np.append(var.alleles, ["N"])
    counter = collections.Counter(alleles[var.genotypes])
    data.append({"position": int(var.position), **{a:counter[a] for a in alleles}})

# %%
df_composition = pd.DataFrame(data, dtype=int)
df_composition
# Out:
#     position        A        C        G        T        -      R     Y      S  \
# 0       4321      555  3347068        5  1115563        4      0  2229      1
# 1       6513     5019        2  3656397      442   772494      9     0      0
# 2       6515     5131       57        4  3656612   772571      0     6      0
# 3      10029        0   807092        0  3660160        0      0   111      0
# 4      15510        3     3167        1  4130426       17      0  1094      0
# 5      21595       42  4269963      181   165995       94      0   791      3
# 6      21610        8     7007       20  4426897      331      0    17      0
# 7      21615        8     7731      958  4424251      250      0    15      0
# 8      21617  4424814     7621      208       25      257     20     0      0
# 9      21621    10856  4408687       21    10786     1241      0   174      7
# 10     21624     7091    26345  4392633     4181     1154     15     1     77
# 11     21627      291  4416767        3    13641      918      0   213      1
# 12     21632       14     6723       56  4424443      549      0    31      0
# 13     21637       53  3313015        9    13269  1104711      0   114      2
# 14     21639     6721  3315800       29     2317  1104695      0   126      4
# 15     21641      214       16  3314975    10495  1104655     23     0      5
# 16     21846      224  2361710       95  1640456       43      0   946      6
# 17     22195       70      474    58135  3549045   703845      0    32      0
# 18     22197       74     2442    57876  4249147      526      0    31      0
# 19     22198  4249665    57736      339       34      485      9     0      0
# 20     22200   122845     1074   984275  3198823      420     35    10      0
# 21     22202    57601  4248400      151      217      414      1    20      0
# 22     22204      670    58082        7  4246687      402      0    18      0
# 23     22674      149  2557988        0  1731782       32      0  1227      0
# 24     22786  3155994  1007824      827      463       14     18    16      1
# 25     22813       60      124  2556032  1530103        4      5    12      3
# 26     22882      843      272  1464971  2522407        7      3    23      0
# 27     23854  1740756  2550088       86     2527       10      4   101      1
# 28     23948      105     2144  2569953  1881771       13      5    16     16
# 29     25000       74  2565003       57  1912083        2      0  1274      3
# 30     26530  3663322       27   746532      116      108  18072     0      0
# 31     26577       58  2566841  1848371        3      123      4     4  20056
# 32     27384       17   807411       19  3624015     1051      0   948      1
# 33     27507  4321318   112428      363      161      885     12     2      0
# 34     27638       33  1705336        4  2488061     7346      0    82      0
# 35     27752       23  2508808       44  1748334     2493      0   151      2
# 36     28095  4292686       28      935   105061     6355     22     1      0
# 37     28916      820        9  2723179  1728031     2796     44     2      0
# 38     29362       27  4422174        4    16090     3881      0  1581      0
#
#        W      K      M  B  D  H  V  .       N
# 0      0      1      8  0  0  0  0  0   18723
# 1      0     14      0  0  0  0  0  0   49780
# 2      0      0      0  0  0  0  0  0   49776
# 3      0      0      0  0  0  0  0  0   16794
# 4      1      1      0  0  0  0  0  0  349447
# 5      0      0      4  0  0  0  0  0   47084
# 6      1      0      0  0  0  0  0  0   49876
# 7      4      5      0  0  0  0  0  0   50935
# 8      4      0     54  0  0  0  0  0   51154
# 9      1      0     23  0  0  0  0  0   52361
# 10     0    113      0  0  0  0  0  0   52547
# 11     0      0     18  0  0  0  0  0   52305
# 12     4      6      0  0  0  0  0  0   52331
# 13     0      0     11  0  0  0  0  0   52973
# 14     0      1      8  0  0  0  0  0   54456
# 15     0    113      0  0  0  0  0  0   53661
# 16     1      3      8  0  0  0  0  0  480665
# 17     3      4      0  0  0  0  0  0  172549
# 18     2      1      0  0  0  0  0  0  174058
# 19    15      0      0  0  0  0  0  0  175874
# 20    47     18      1  0  0  0  0  0  176609
# 21     0      0      3  0  0  0  0  0  177350
# 22     4      0      0  0  0  0  0  0  178287
# 23     4      0      0  0  0  0  0  0  192975
# 24     9      0  29256  0  0  0  0  0  289735
# 25     1   2956      0  0  0  0  0  0  394857
# 26    47  12268      0  0  0  0  0  0  483316
# 27     3      0    508  0  0  0  0  0  190073
# 28     1   1817      0  0  0  0  0  0   28316
# 29     0      2      6  0  0  0  0  0    5653
# 30     9     13      5  0  0  0  0  0   55953
# 31     0      4      4  0  0  0  0  0   48689
# 32     0      3      2  0  0  0  0  0   50690
# 33     3      0    937  0  0  0  0  0   48048
# 34     0      0      2  0  0  0  0  0  283293
# 35     0      0      2  0  0  0  0  0  224300
# 36  1995      0      2  0  0  0  0  0   77072
# 37     0    237      0  0  0  0  0  0   29039
# 38     0      0      3  0  0  0  0  0   40397

# %%
np.sum(df_composition["-"] > 500_000)
# Out:
# np.int64(6)

# %% [markdown]
# Of the 39 sites where we don't exactly reproduce the confident calls in the alignment, we have 6 sites that have more than 500,000 samples called as a gap character. It seems likely these are driven by differences in the alignment or perhaps or other factors.
