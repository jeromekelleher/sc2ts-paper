# %%
import tskit
import tszip
import numpy as np
import pandas as pd
import sc2ts

# %%
ds = sc2ts.Dataset("../data/viridian_mafft_2024-10-14_v1.vcz.zip")

# %%
ts = tszip.load("all_viridian.202409.trees.tsz")

# %%
# %%time
df_nodes = sc2ts.node_data(ts)
# Out:
# CPU times: user 2.63 s, sys: 339 ms, total: 2.97 s
# Wall time: 2.97 s

# %%
# %%time
df_muts = sc2ts.mutation_data(ts)
# Out:
# CPU times: user 1.15 s, sys: 0 ns, total: 1.15 s
# Wall time: 1.15 s

# %%
df_muts
# Out:
#          mutation_id  position  parent     node inherited_state derived_state  \
# 0                  0       267      -1  1235535               T             A
# 1                  1       267      -1  5297533               T             G
# 2                  2       269      -1   246856               G             A
# 3                  3       269      -1  2677518               G             A
# 4                  4       269      -1  4780608               G             A
# ...              ...       ...     ...      ...             ...           ...
# 3364836      3364836     29671      -1  4571321               A             G
# 3364837      3364837     29671      -1  4525231               A             T
# 3364838      3364838     29671      -1  4622571               A             G
# 3364839      3364839     29671      -1  4520611               A             T
# 3364840      3364840     29671      -1  2532777               A             G
#
#          num_descendants  num_inheritors       date
# 0                      1               1 2024-06-06
# 1                      1               1 2024-06-06
# 2                     12              12 2024-06-01
# 3                     75              75 2024-06-01
# 4                     26              26 2024-06-01
# ...                  ...             ...        ...
# 3364836                1               1 2024-06-06
# 3364837                1               1 2024-06-06
# 3364838                1               1 2024-06-06
# 3364839                1               1 2024-06-06
# 3364840                1               1 2024-06-06
#
# [3364841 rows x 9 columns]

# %%
df_nodes
# Out:
#             pango    sample_id  node_id  is_sample  is_recombinant  \
# 0               B   ERR4085584        0       True           False
# 1               B   ERR4086315        1       True           False
# 2               B   ERR4091746        2       True           False
# 3               B   ERR4165155        3       True           False
# 4               B   ERR4204267        4       True           False
# ...           ...          ...      ...        ...             ...
# 5345014  BA.5.2.1  SRR21886505  5345014       True           False
# 5345015            node_763111  5345015      False           False
# 5345016  BA.5.2.1  SRR21635465  5345016       True           False
# 5345017            node_763112  5345017      False           False
# 5345018  BA.5.2.1  SRR21795271  5345018       True           False
#
#          num_mutations  max_descendant_samples       date
# 0                    0                       1 2024-06-06
# 1                    0                       1 2024-06-06
# 2                    0                       1 2024-06-06
# 3                    0                       1 2024-06-06
# 4                    0                       1 2024-06-06
# ...                ...                     ...        ...
# 5345014              5                       1 2024-06-06
# 5345015              1                       3 2024-06-04
# 5345016              0                       1 2024-06-06
# 5345017              1                       2 2024-06-05
# 5345018              0                       1 2024-06-06
#
# [5345019 rows x 8 columns]

# %%
df_samples = df_nodes[df_nodes.is_sample].set_index("sample_id")

# %%
ds.metadata.field_descriptors()
# Out:
#                        field   dtype  \
# 0       Artic_primer_version  object
# 1            Collection_date  object
# 2                    Country  object
# 3                  Date_tree  object
# 4            Date_tree_order  object
# 5                 Experiment  object
# 6              First_created  object
# 7                  Genbank_N   int16
# 8          Genbank_accession  object
# 9         Genbank_other_runs  object
# 10          Genbank_pangolin  object
# 11           Genbank_scorpio  object
# 12         Genbank_tree_name  object
# 13          In_Viridian_tree    bool
# 14           In_intersection    bool
# 15      In_may_2024_preprint    bool
# 16                  Platform  object
# 17                    Region  object
# 18                 Run_count    int8
# 19                    Sample  object
# 20                     Study  object
# 21                Viridian_N   int16
# 22  Viridian_amplicon_scheme  object
# 23         Viridian_cons_het    int8
# 24         Viridian_cons_len   int16
# 25         Viridian_pangolin  object
# 26    Viridian_pangolin_1.29  object
# 27           Viridian_result  object
# 28          Viridian_scorpio  object
# 29     Viridian_scorpio_1.29  object
#
#                                           description
# 0   If known, the ARTIC primer scheme from ENA met...
# 1                   collection_date from ENA metadata
# 2   Country from ENA metadata. If ':' was in the e...
# 3   A consensus date, using up 3 sources of data f...
# 4   This helped define the order in which the samp...
# 5              experiment_accession from ENA metadata
# 6                 first_created from the ENA metadata
# 7   Number of Ns in the GenBank consensus sequence...
# 8       This is the GenBank accession of the assembly
# 9   Any other run accessions associated with the G...
# 10  Pangolin call from the GenBank consensus seque...
# 11  Scorpio call from the GenBank consensus sequen...
# 12             Name of the sample in the GenBank tree
# 13  'T' or 'F' to indicate if the sample is in the...
# 14  'T' or 'F' to indicate if the sample is in the...
# 15  Whether or not this run was in the May 2024 pr...
# 16              instrument_platform from ENA metadata
# 17  Region from ENA metadata, if present. If ':' w...
# 18       The number of runs from the sample accession
# 19                 sample_accession from ENA metadata
# 20                  study_accession from ENA metadata
# 21  Number of Ns in the viridian consensus sequenc...
# 22                 Amplicon scheme called by Viridian
# 23
# 24  Length of the Viridian consensus sequence Viri...
# 25  Pangolin call from the Viridian consensus sequ...
# 26  Pangolin call from the Viridian consensus sequ...
# 27  This is 'PASS' if Viridian finished and made a...
# 28  Scorpio call from the Viridian consensus seque...
# 29  Scorpio call from the Viridian consensus seque...

# %%
# Add some fields in 
df_samples = df_samples.join(ds.metadata.as_dataframe(["Country", "Viridian_pangolin_1.29"]))
df_samples
# Out:
#                 pango  node_id  is_sample  is_recombinant  num_mutations  \
# sample_id
# ERR4085584          B        0       True           False              0
# ERR4086315          B        1       True           False              0
# ERR4091746          B        2       True           False              0
# ERR4165155          B        3       True           False              0
# ERR4204267          B        4       True           False              0
# ...               ...      ...        ...             ...            ...
# SRR20933483  BA.5.2.1  5345012       True           False              1
# SRR21370322  BA.5.2.1  5345013       True           False              1
# SRR21886505  BA.5.2.1  5345014       True           False              5
# SRR21635465  BA.5.2.1  5345016       True           False              0
# SRR21795271  BA.5.2.1  5345018       True           False              0
#
#              max_descendant_samples       date         Country  \
# sample_id
# ERR4085584                        1 2024-06-06  United Kingdom
# ERR4086315                        1 2024-06-06  United Kingdom
# ERR4091746                        1 2024-06-06  United Kingdom
# ERR4165155                        1 2024-06-06  United Kingdom
# ERR4204267                        1 2024-06-06  United Kingdom
# ...                             ...        ...             ...
# SRR20933483                       1 2024-06-06             USA
# SRR21370322                       1 2024-06-06             USA
# SRR21886505                       1 2024-06-06             USA
# SRR21635465                       1 2024-06-06             USA
# SRR21795271                       1 2024-06-06             USA
#
#             Viridian_pangolin_1.29
# sample_id
# ERR4085584                       B
# ERR4086315                       B
# ERR4091746                       B
# ERR4165155                       B
# ERR4204267                       B
# ...                            ...
# SRR20933483               BA.5.2.1
# SRR21370322               BA.5.2.1
# SRR21886505               BA.5.2.1
# SRR21635465               BA.5.2.1
# SRR21795271               BA.5.2.1
#
# [4471579 rows x 9 columns]

# %% [markdown]
# # Check metadata round trip
#
# Check that we've successfully roundtripped the metadata from the MAT through tskit and via minimisation. We have used the Viridian_pangolin_1.29 field, which should be identical for all samples.

# %%
np.all(df_samples["pango"] == df_samples["Viridian_pangolin_1.29"])
# Out:
# np.True_
